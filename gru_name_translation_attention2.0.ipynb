# %% [markdown]
# ## %autosave 60
# import random

# %%
# %autosave 60
import random
import datetime
print(datetime.datetime.now())
# Out:
# Autosaving every 60 seconds
# 2021-03-10 00:17:26.377323

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-


import pandas as pd
with open('data/names.csv', 'r',  encoding="utf-8")as f:
    string = ""

    
    line = f.readline()

    
    
    while line:
        
        if len(line) > 2 and line[-2] == ',':
            line = line[:-2] + '\n'
        if len(line) > 2 and line[-2] == '.':
            line = line[:-2] + '\n'
        if '’' in line:
            line = line.replace("’", "\'")
        if '׳' in line:
            line = line.replace("׳", "\'")
        if 'ʼ' in line:
            line = line.replace('ʼ', "")
        if 'ʾ' in line:
            line = line.replace('ʾ', "")
        if 'ʹ' in line:
            line = line.replace('ʹ', "")
        if 'ʿ' in line:
            line = line.replace('ʿ', "")
        if 'ӏ' in line:
            line = line.replace('ӏ', "l")
        if '–' in line:
            line = line.replace('–', "-")
        
        
        
        if ",," in line:
            # print(line)
            
            line = line.replace(",,", ",")
        if '\'' in line:
            line = line.replace('\'', '\\\'')
        if '\"' in line:
            line = line.replace('\"', '\\\"')
        if '(' in line or ')' in line:
            line = ""
        if line == 'hebrew,english\n':
            # print(index)
            line= ""
        string += line
        line = f.readline()


with open('data/names_after_processing.csv', 'w',  encoding="utf-8") as fi:
    fi.write(string)

df = pd.read_csv("data/names_after_processing.csv", names=['hebrew', 'english'],header=None)
# print(len(df))
wierd_charachters =  ['װ','í', 'á', 'ó', 'č',  'š', 'ş',  'ł',  'ø', 'é', 'ő', 'î', 'è', 'ć', 'ž', 'ö', 'ň', 'ẓ', 'ü', 'ť', 'ý', 'ã', 'ë', 'ī', 'ḥ', 'ă', 'ñ', 'ä', '־', 'ʻ', 'ğ', 'ï', 'ģ', 'ń', 'ç', 'ū', 'ú', 'ļ', 'ṭ', 'å', 'ḳ', '̈', '1', 'ĥ', 'ð', 'ě', 'ō', 'ô', 'ė', 'ò', 'ř', 'ț',  'ą', 'ß', 'đ', '\xa0', ':', 'æ', 'ê', 'â', 'ı', 'ù', 'à', 'ś', '︠', '︡',  'ż',  'ţ', 'þ', 'ľ',  'ā', '0', 'ų', 'ĭ', '8', 'ē', 'ņ', 'ÿ', 'ַ', 'θ', 'ε', 'δ', 'ω', 'ρ', 'α', 'ό', 'π', 'υ', 'λ', 'ς', '3', 'õ', 'م', 'ا', 'ل', 'ي', 'ن', '،', 'ׂ', '$', '5', '2', '室', '田', '一', '雄', '′', 'س', 'ف', 'ầ', 'ů', '͡', 'ŏ', 'ả', 'ź', 'ì', '̣', 'ب', 'ر', 'و', 'ױ', '_', 'ə', 'û', 'ŭ', 'د', '9', 'ṣ', 'ḵ', '6', 'أ', 'ك', 'گ', 'ی', '!', 'ت',  'ď', '4', 'ŵ', 'ķ', 'ش', 'ứ', '7', 'œ', 'ũ', 'ű', 'ụ', 'ه', 'ạ', 'ح', 'ذ', 'τ', 'ά', 'ι', 'ṇ','ę', '׳', 'ׂ', '̇', '’', '.', '־', '/', 'ִ', 'ְ', 'ּ', 'ș', 'ʼ', 'ֶ', 'ַ', 'ʾ', '室', '田', '一', '雄', 'ײ', '‘', 'ʹ', 'ׁ', ':', '[', 'س', 'ي', 'ف', 'ر', 'ت', 'ֹ', 'ا', 'ن', 'ṿ', 'ָ', 'ֵ', '!', 'ʿ', '_', 'أ', 'ب', 'و', '`', '1', '0', '8', 'ش', 'ل', 'κ', 'ӏ', 'ׄ', 'م', 'د', '2', 'τ', 'ά', 'ι', 'θ', 'ε', 'ο', 'δ', 'ω', 'ρ', 'α', 'ό', 'π', 'υ', 'λ', 'ς', '\xa0', '،', '״', 'ױ', '5', 'ك']

df.drop(df[(df['english'] == 'i')|
(df['english'] == 'ii')|(df['english'] == 'iii')
|(df['english'] == 'iv')|(df['english'] == 'v')
|(df['english'] == 'vi')|(df['english'] == 'vii')
|(df['english'] == 'viii')|(df['english'] == 'ix')
|(df['english'] == 'x')|(df['english'] == 'xi')
|(df['english'] == 'xii')|(df['english'] == 'xiii')
|(df['english'] == 'prince')|(df['english'] == 'princess')
|(df['english'] == 'dutchess')|(df['english'] == 'duke')
|(df['english'] == 'mr')|(df['english'] == 'ms')|(df['english'] == 'mrs')
|(df['english'] == 'the')|(df['english'] == 'for')|(df['english'] == 'of')
|(df['english'] == 'king')|(df['english'] == 'queen')|(df['english'] == 'is')
|(df['english'].str.contains('^[a-z][.]', regex =True))|(df['english'].str.contains('^[א-ת][.]', regex =True))
|(df['english'].str.contains('^[a-z]$', regex =True))|(df['english'].str.contains('^[א-ת]$', regex =True))
].index, inplace=True)

df.dropna(axis=0, how='any',  inplace=True)

for char in wierd_charachters:
    df.drop(df[(df['english'].str.contains(char, regex=False))|(df['hebrew'].str.contains(char, regex=False)) ].index, inplace=True)
    
df.dropna(axis=0, how='any',  inplace=True)

df.drop(df.loc[df['english'].str.contains('[א-ת]', regex=True)].index, inplace=True)

df.dropna(axis=0, how='any',  inplace=True)


df.reset_index(drop=True, inplace=True)

df.to_csv('names_final.csv', index = False)
print(len(df))
df.drop_duplicates(inplace=True, ignore_index=True)
print(len(df))
# Out:
# 254928
# 87564

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torch
import torch.nn.functional as F

def train_validate_test_split(dataframe, train_percent=.9,validate_percent=0.0, seed=42):
    np.random.seed(seed)
    perm = np.random.permutation(dataframe.index)
   
    m = len(dataframe.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    print(max(perm))
    
    train = dataframe.iloc[perm[:train_end]]
    validate = dataframe.iloc[perm[train_end:validate_end]]
    test = dataframe.iloc[perm[validate_end:]]
    
    return train, validate, test

# %%
MAX_LABEL_LENGTH = 12
MAX_INPUT_LENGTH = 14
class Vocab:
    def __init__(self, is_hebrew):
        self.char2id = {}
        self.id2char = {}
        if is_hebrew:
            self.n_chars = 2        
            self.char2id['^'] = 0
            self.char2id['$'] = 1
            self.id2char[0] = '^'
            self.id2char[1] = '$'
        else:
            self.n_chars = 0
            
        
        
        
        
    def index_text(self, text):
        indexes = [self.index_char(c) for c in text]
        return indexes
    
    def index_char(self, c):
        if c not in self.char2id:
            self.char2id[c] = self.n_chars
            self.id2char[self.n_chars] = c
            self.n_chars += 1
        return self.char2id[c]
            
            
def load_data(data, vocab_english, vocab_hebrew):
    data_sequences = []
    max_word = 0
    num_more_than_20 = 0 
    max_word_value = None
    num_english = 0
    for text in data.itertuples():
        indexes_english = vocab_english.index_text(text.english)
        indexes_hebrew = vocab_hebrew.index_text(text.hebrew)
        
        if len(indexes_hebrew) > max_word:
            max_word = len(indexes_hebrew)
            max_word_value = indexes_hebrew
        if len(indexes_hebrew) <= MAX_LABEL_LENGTH:
            for i in range(len(indexes_hebrew),MAX_LABEL_LENGTH, 1):
                indexes_hebrew.append(1)
        if len(indexes_english) <= MAX_INPUT_LENGTH:
            for i in range(len(indexes_english), MAX_INPUT_LENGTH, 1):
                indexes_english.append(1)
        if len(indexes_english) <= MAX_INPUT_LENGTH and len(indexes_hebrew) <= MAX_LABEL_LENGTH:
            data_sequences.append((indexes_english, indexes_hebrew))
        
    
    return data_sequences

vocab_english = Vocab(False)
vocab_hebrew = Vocab(True)
train_set, validation_set, test_set = train_validate_test_split(dataframe=df)

train_data = load_data(train_set,vocab_english, vocab_hebrew)

dev_data = load_data(validation_set,vocab_english, vocab_hebrew)

test_data = load_data(test_set,vocab_english, vocab_hebrew)



print(f'Train size {len(train_data)}, Dev size {len(dev_data)}, Test size {len(test_data)} vocab english size {vocab_english.n_chars} vocab hebrew size {vocab_hebrew.n_chars}')
# Out:
# 87563
# Train size 78002, Dev size 0, Test size 8675 vocab english size 30 vocab hebrew size 34

# %%
small_train_data = train_data[:8000]
print(len(small_train_data))
# Out:
# 8000

# %%
class GRU_encoder(nn.Module):
    def __init__(self, input_size, hidden_size, embedding_size, layers=1):
        super(GRU_encoder, self).__init__()
        self.num_of_layers = layers
        self.hidden_size = hidden_size
        self.input_size = input_size
        
        self.embedding = nn.Embedding(input_size, embedding_size).cuda()
        
        self.rnn = nn.GRU(embedding_size, hidden_size, num_layers=layers).cuda()
        
    def forward(self, input_letter, hidden):
        output = self.embedding(input_letter)
        
        
        
        output, hidden = self.rnn(output, hidden)
        
        return output, hidden
        
    def initHidden(self):
        return torch.zeros(self.num_of_layers, 1, self.hidden_size).cuda()

# %%
class GRU_decoder(nn.Module):
    def __init__(self,  output_size, hidden_size, embedding_size, layers=1, dropout=0.1):
        super(GRU_decoder, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout = dropout
        self.num_of_layers = layers
        

        self.embedding = nn.Embedding(self.output_size, self.hidden_size).cuda()
        self.linear = nn.Linear(self.hidden_size * 2, MAX_INPUT_LENGTH).cuda()
        
        self.linear_layers = nn.Linear(self.num_of_layers * MAX_INPUT_LENGTH, MAX_INPUT_LENGTH).cuda()
        
        self.linear_attention = nn.Linear(self.hidden_size * 2, self.hidden_size).cuda()
        self.dropout = nn.Dropout(self.dropout).cuda()
        self.gru = nn.GRU(self.hidden_size, self.hidden_size, num_layers=layers).cuda()
        self.out = nn.Linear(self.hidden_size, self.output_size).cuda()

    def forward(self, letter, hidden, encoder_outputs):
        embedded = self.embedding(letter)
#         embedded = self.dropout(embedded)
        
#         output = self.embedding(letter)
#         output = self.dropout(output)
        
#         print(embedded.size())
#         print(hidden.size())
        sum_of_layers = torch.zeros(1, self.hidden_size)
        
        weights_layers = torch.empty(self.num_of_layers * MAX_INPUT_LENGTH).cuda()
        
        for i in range(self.num_of_layers):
            
            output = torch.cat((embedded[0][0], hidden[i][0]))
            output = self.linear(output)
    #             print(output.size())
#             weights = F.softmax(output)
            weights = output
            
#             print(weights.size())
    #             print(output.size())
            if i == 0:
                weights_layers = weights
            else:
                weights_layers = torch.cat((weights_layers, weights))

    #             weights = F.softmax(
    #                 self.attn(torch.cat((output[0], hidden[0]), 1)), dim=1)
    #             print(encoder_outputs.size())
#         print(weights_layers.size())
#         print(self.num_of_layers * MAX_INPUT_LENGTH)
        weights = self.linear_layers(weights_layers)
        weights = F.softmax(weights)
    
        encoder_outputs = encoder_outputs.reshape(encoder_outputs.shape[0], encoder_outputs.shape[2])
#             print(len(weights))
        
        
        weights = weights.reshape(1, len(weights))
        attn_applied = torch.mm(weights, encoder_outputs)

#             print(attn_applied.size())
#             print(embedded.size())
#             print(attn_applied.size())
#             print(attn_applied.size())
        output = torch.cat((embedded[0][0], attn_applied[0]))
#         print(output.size())
        output = self.linear_attention(output)

        output = F.relu(output)
        output = output.reshape(1,1,self.hidden_size)
        
        output, hidden = self.gru(output, hidden)
        
        output = self.out(output)
#         print(output.size())
        return output, hidden

# %%
# class seq2seq_GRU(nn.Module):
    
#     def __init__(self, input_size, output_size, hidden_size, embedding_size):
#         super(seq2seq_GRU, self).__init__()
        
#         self.encoder = GRU_encoder(input_size=input_size, hidden_size=hidden_size, embedding_size=embedding_size)
                
#         self.decoder = GRU_decoder(output_size=output_size, hidden_size=hidden_size, embedding_size=embedding_size)
        
        
#     def forward(self, input_word):
#         output, hidden = self.encoder(input_word)
        
#         output = self.decoder(, hidden)

# %%
encoder_model_3 = GRU_encoder(vocab_english.n_chars, 300, 64, layers=2)
decoder_model_3 = GRU_decoder(vocab_hebrew.n_chars, 300, 64, layers=2)

encoder_optimizer_3 = optim.Adam(params=encoder_model_3.parameters(), lr=0.0001)
decoder_optimizer_3 = optim.Adam(params=decoder_model_3.parameters(), lr=0.0001)

critertion_3 = nn.CrossEntropyLoss()

# %%
def train_3(n_epochs=4, print_every=5000):
    loss = 0

    for e in range(1, n_epochs + 1):

        for counter, (english_name, hebrew_name) in enumerate(train_data):
            encoder_hidden = encoder_model_3.initHidden()

            encoder_optimizer_3.zero_grad()
            decoder_optimizer_3.zero_grad()

    #         english_name_tensor = torch.LongTensor(english_name).cuda()
            encoder_outputs = torch.ones(MAX_INPUT_LENGTH, 1, encoder_model_3.hidden_size).cuda()
    #         hebrew_name_tensor = torch.LongTensor(hebrew_name).cuda()
    
            for i, letter in enumerate(english_name):
                letter_tensor = torch.tensor([[letter]]).cuda()
                encoder_output, encoder_hidden = encoder_model_3(letter_tensor, encoder_hidden)
                
                encoder_outputs[i] = encoder_output
            
            decoder_input = torch.tensor([[0]]).cuda()
            decoder_hidden = encoder_hidden
            
            transliration_loss = 0 
            
            
            for i in range(len(hebrew_name)):
                decoder_output, decoder_hidden = decoder_model_3(decoder_input, decoder_hidden, encoder_outputs)
#                 print(i)
                
                
                _, top_indexes = decoder_output.topk(1)

                decoder_input = top_indexes.squeeze(0).detach()
#                 return
                
#                 print(decoder_hidden.size())
                transliration_loss += critertion_3(decoder_output.reshape(decoder_output.shape[1], decoder_output.shape[2]), torch.tensor([hebrew_name[i]]).cuda())
                if decoder_input.item() == [1]:
                    break
#             return 
            transliration_loss.backward()

            encoder_optimizer_3.step()
            decoder_optimizer_3.step()

            loss += transliration_loss.item() / len(hebrew_name)


            if counter % print_every == 0 and counter != 0:
                loss = loss / print_every
                print('Epoch %d,/%d, Current Loss = %.4f' % (e, counter,loss))
                loss = 0

# %%
train_3(print_every=100)
# Out:
# <ipython-input-9-71cb0f34e1fa>:54: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   weights = F.softmax(weights)
# Epoch 1,/100, Current Loss = 2.0416
# Epoch 1,/200, Current Loss = 1.7606
# Epoch 1,/300, Current Loss = 1.6296
# Epoch 1,/400, Current Loss = 1.5724
# Epoch 1,/500, Current Loss = 1.5889
# Epoch 1,/600, Current Loss = 1.6141
# Epoch 1,/700, Current Loss = 1.5154
# Epoch 1,/800, Current Loss = 1.5524
# Epoch 1,/900, Current Loss = 1.6025
# Epoch 1,/1000, Current Loss = 1.5585
# Epoch 1,/1100, Current Loss = 1.4687
# Epoch 1,/1200, Current Loss = 1.4741
# Epoch 1,/1300, Current Loss = 1.5016
# Epoch 1,/1400, Current Loss = 1.5050
# Epoch 1,/1500, Current Loss = 1.6053
# Epoch 1,/1600, Current Loss = 1.5127
# Epoch 1,/1700, Current Loss = 1.5699
# Epoch 1,/1800, Current Loss = 1.5360
# Epoch 1,/1900, Current Loss = 1.6429
# Epoch 1,/2000, Current Loss = 1.5421
# Epoch 1,/2100, Current Loss = 1.5863
# Epoch 1,/2200, Current Loss = 1.5366
# Epoch 1,/2300, Current Loss = 1.5577
# Epoch 1,/2400, Current Loss = 1.5251
# Epoch 1,/2500, Current Loss = 1.5302
# Epoch 1,/2600, Current Loss = 1.5857
# Epoch 1,/2700, Current Loss = 1.5558
# Epoch 1,/2800, Current Loss = 1.5023
# Epoch 1,/2900, Current Loss = 1.5237
# Epoch 1,/3000, Current Loss = 1.5431
# Epoch 1,/3100, Current Loss = 1.5230
# Epoch 1,/3200, Current Loss = 1.5323
# Epoch 1,/3300, Current Loss = 1.4498
# Epoch 1,/3400, Current Loss = 1.4844
# Epoch 1,/3500, Current Loss = 1.3768
# Epoch 1,/3600, Current Loss = 1.4435
# Epoch 1,/3700, Current Loss = 1.5275
# Epoch 1,/3800, Current Loss = 1.5399
# Epoch 1,/3900, Current Loss = 1.5149
# Epoch 1,/4000, Current Loss = 1.4395
# Epoch 1,/4100, Current Loss = 1.4383
# Epoch 1,/4200, Current Loss = 1.4924
# Epoch 1,/4300, Current Loss = 1.5263
# Epoch 1,/4400, Current Loss = 1.4608
# Epoch 1,/4500, Current Loss = 1.4373
# Epoch 1,/4600, Current Loss = 1.4575
# Epoch 1,/4700, Current Loss = 1.3707
# Epoch 1,/4800, Current Loss = 1.4736
# Epoch 1,/4900, Current Loss = 1.4514
# Epoch 1,/5000, Current Loss = 1.5271
# Epoch 1,/5100, Current Loss = 1.5124
# Epoch 1,/5200, Current Loss = 1.3850
# Epoch 1,/5300, Current Loss = 1.4710
# Epoch 1,/5400, Current Loss = 1.4976
# Epoch 1,/5500, Current Loss = 1.4516
# Epoch 1,/5600, Current Loss = 1.4139
# Epoch 1,/5700, Current Loss = 1.4185
# Epoch 1,/5800, Current Loss = 1.4350
# Epoch 1,/5900, Current Loss = 1.3841
# Epoch 1,/6000, Current Loss = 1.4470
# Epoch 1,/6100, Current Loss = 1.4837
# Epoch 1,/6200, Current Loss = 1.3956
# Epoch 1,/6300, Current Loss = 1.4129
# Epoch 1,/6400, Current Loss = 1.5069
# Epoch 1,/6500, Current Loss = 1.4709
# Epoch 1,/6600, Current Loss = 1.5023
# Epoch 1,/6700, Current Loss = 1.3867
# Epoch 1,/6800, Current Loss = 1.3904
# Epoch 1,/6900, Current Loss = 1.4730
# Epoch 1,/7000, Current Loss = 1.4150
# Epoch 1,/7100, Current Loss = 1.3715
# Epoch 1,/7200, Current Loss = 1.4359
# Epoch 1,/7300, Current Loss = 1.3925
# Epoch 1,/7400, Current Loss = 1.4660
# Epoch 1,/7500, Current Loss = 1.3056
# Epoch 1,/7600, Current Loss = 1.3896
# Epoch 1,/7700, Current Loss = 1.3103
# Epoch 1,/7800, Current Loss = 1.3257
# Epoch 1,/7900, Current Loss = 1.3418
# Epoch 1,/8000, Current Loss = 1.2487
# Epoch 1,/8100, Current Loss = 1.3131
# Epoch 1,/8200, Current Loss = 1.3821
# Epoch 1,/8300, Current Loss = 1.4485
# Epoch 1,/8400, Current Loss = 1.3040
# Epoch 1,/8500, Current Loss = 1.3923
# Epoch 1,/8600, Current Loss = 1.2359
# Epoch 1,/8700, Current Loss = 1.2196
# Epoch 1,/8800, Current Loss = 1.2465
# Epoch 1,/8900, Current Loss = 1.2082
# Epoch 1,/9000, Current Loss = 1.2525
# Epoch 1,/9100, Current Loss = 1.3711
# Epoch 1,/9200, Current Loss = 1.1959
# Epoch 1,/9300, Current Loss = 1.2001
# Epoch 1,/9400, Current Loss = 1.3560
# Epoch 1,/9500, Current Loss = 1.3306
# Epoch 1,/9600, Current Loss = 1.3819
# Epoch 1,/9700, Current Loss = 1.2425
# Epoch 1,/9800, Current Loss = 1.3578
# Epoch 1,/9900, Current Loss = 1.2459
# Epoch 1,/10000, Current Loss = 1.2666
# Epoch 1,/10100, Current Loss = 1.2776
# Epoch 1,/10200, Current Loss = 1.2305
# Epoch 1,/10300, Current Loss = 1.3487
# Epoch 1,/10400, Current Loss = 1.2653
# Epoch 1,/10500, Current Loss = 1.3378
# Epoch 1,/10600, Current Loss = 1.2786
# Epoch 1,/10700, Current Loss = 1.2374
# Epoch 1,/10800, Current Loss = 1.2152
# Epoch 1,/10900, Current Loss = 1.3342
# Epoch 1,/11000, Current Loss = 1.1265
# Epoch 1,/11100, Current Loss = 1.2184
# Epoch 1,/11200, Current Loss = 1.1983
# Epoch 1,/11300, Current Loss = 1.2290
# Epoch 1,/11400, Current Loss = 1.2148
# Epoch 1,/11500, Current Loss = 1.1738
# Epoch 1,/11600, Current Loss = 1.1753
# Epoch 1,/11700, Current Loss = 1.1393
# Epoch 1,/11800, Current Loss = 1.0804
# Epoch 1,/11900, Current Loss = 1.1417
# Epoch 1,/12000, Current Loss = 1.1753
# Epoch 1,/12100, Current Loss = 1.0711
# Epoch 1,/12200, Current Loss = 1.1196
# Epoch 1,/12300, Current Loss = 1.1979
# Epoch 1,/12400, Current Loss = 1.2669
# Epoch 1,/12500, Current Loss = 1.1838
# Epoch 1,/12600, Current Loss = 1.1463
# Epoch 1,/12700, Current Loss = 1.1066
# Epoch 1,/12800, Current Loss = 1.0673
# Epoch 1,/12900, Current Loss = 1.1988
# Epoch 1,/13000, Current Loss = 1.0407
# Epoch 1,/13100, Current Loss = 1.1724
# Epoch 1,/13200, Current Loss = 1.0046
# Epoch 1,/13300, Current Loss = 1.1559
# Epoch 1,/13400, Current Loss = 1.1035
# Epoch 1,/13500, Current Loss = 1.1371
# Epoch 1,/13600, Current Loss = 1.1763
# Epoch 1,/13700, Current Loss = 1.1235
# Epoch 1,/13800, Current Loss = 1.1470
# Epoch 1,/13900, Current Loss = 1.0667
# Epoch 1,/14000, Current Loss = 1.0372
# Epoch 1,/14100, Current Loss = 1.0441
# Epoch 1,/14200, Current Loss = 1.0388
# Epoch 1,/14300, Current Loss = 1.0859
# Epoch 1,/14400, Current Loss = 1.0284
# Epoch 1,/14500, Current Loss = 0.9508
# Epoch 1,/14600, Current Loss = 1.0094
# Epoch 1,/14700, Current Loss = 1.1900
# Epoch 1,/14800, Current Loss = 1.0189
# Epoch 1,/14900, Current Loss = 1.0925
# Epoch 1,/15000, Current Loss = 1.0941
# Epoch 1,/15100, Current Loss = 1.1218
# Epoch 1,/15200, Current Loss = 1.1295
# Epoch 1,/15300, Current Loss = 1.1822
# Epoch 1,/15400, Current Loss = 1.0740
# Epoch 1,/15500, Current Loss = 1.1426
# Epoch 1,/15600, Current Loss = 1.0519
# Epoch 1,/15700, Current Loss = 0.9695
# Epoch 1,/15800, Current Loss = 1.0283
# Epoch 1,/15900, Current Loss = 0.9885
# Epoch 1,/16000, Current Loss = 1.0882
# Epoch 1,/16100, Current Loss = 1.1859
# Epoch 1,/16200, Current Loss = 0.9478
# Epoch 1,/16300, Current Loss = 0.9746
# Epoch 1,/16400, Current Loss = 1.0427
# Epoch 1,/16500, Current Loss = 1.0077
# Epoch 1,/16600, Current Loss = 0.9688
# Epoch 1,/16700, Current Loss = 0.9402
# Epoch 1,/16800, Current Loss = 1.0265
# Epoch 1,/16900, Current Loss = 1.0014
# Epoch 1,/17000, Current Loss = 0.9922
# Epoch 1,/17100, Current Loss = 0.9467
# Epoch 1,/17200, Current Loss = 1.0264
# Epoch 1,/17300, Current Loss = 1.0587
# Epoch 1,/17400, Current Loss = 0.9088
# Epoch 1,/17500, Current Loss = 0.9229
# Epoch 1,/17600, Current Loss = 0.9998
# Epoch 1,/17700, Current Loss = 0.9410
# Epoch 1,/17800, Current Loss = 1.0148
# Epoch 1,/17900, Current Loss = 0.9715
# Epoch 1,/18000, Current Loss = 0.9616
# Epoch 1,/18100, Current Loss = 0.9928
# Epoch 1,/18200, Current Loss = 0.8767
# Epoch 1,/18300, Current Loss = 0.9571
# Epoch 1,/18400, Current Loss = 1.0151
# Epoch 1,/18500, Current Loss = 1.0305
# Epoch 1,/18600, Current Loss = 0.9133
# Epoch 1,/18700, Current Loss = 0.9883
# Epoch 1,/18800, Current Loss = 1.0432
# Epoch 1,/18900, Current Loss = 1.0774
# Epoch 1,/19000, Current Loss = 1.0590
# Epoch 1,/19100, Current Loss = 0.8165
# Epoch 1,/19200, Current Loss = 1.0476
# Epoch 1,/19300, Current Loss = 0.9240
# Epoch 1,/19400, Current Loss = 0.9530
# Epoch 1,/19500, Current Loss = 0.9273
# Epoch 1,/19600, Current Loss = 0.8721
# Epoch 1,/19700, Current Loss = 0.9410
# Epoch 1,/19800, Current Loss = 1.0488
# Epoch 1,/19900, Current Loss = 0.8480
# Epoch 1,/20000, Current Loss = 0.8584
# Epoch 1,/20100, Current Loss = 0.8415
# Epoch 1,/20200, Current Loss = 0.9470
# Epoch 1,/20300, Current Loss = 0.9138
# Epoch 1,/20400, Current Loss = 0.9655
# Epoch 1,/20500, Current Loss = 1.0534
# Epoch 1,/20600, Current Loss = 0.9369
# Epoch 1,/20700, Current Loss = 0.9677
# Epoch 1,/20800, Current Loss = 0.8577
# Epoch 1,/20900, Current Loss = 0.9804
# Epoch 1,/21000, Current Loss = 0.9082
# Epoch 1,/21100, Current Loss = 0.8630
# Epoch 1,/21200, Current Loss = 0.8180
# Epoch 1,/21300, Current Loss = 0.8925
# Epoch 1,/21400, Current Loss = 0.9661
# Epoch 1,/21500, Current Loss = 0.9358
# Epoch 1,/21600, Current Loss = 0.8597
# Epoch 1,/21700, Current Loss = 1.0075
# Epoch 1,/21800, Current Loss = 0.8597
# Epoch 1,/21900, Current Loss = 0.9499
# Epoch 1,/22000, Current Loss = 0.8061
# Epoch 1,/22100, Current Loss = 0.9027
# Epoch 1,/22200, Current Loss = 0.9021
# Epoch 1,/22300, Current Loss = 0.8601
# Epoch 1,/22400, Current Loss = 0.8629
# Epoch 1,/22500, Current Loss = 0.8530
# Epoch 1,/22600, Current Loss = 0.8740
# Epoch 1,/22700, Current Loss = 1.0716
# Epoch 1,/22800, Current Loss = 0.8239
# Epoch 1,/22900, Current Loss = 0.9476
# Epoch 1,/23000, Current Loss = 0.9208
# Epoch 1,/23100, Current Loss = 0.9772
# Epoch 1,/23200, Current Loss = 0.9547
# Epoch 1,/23300, Current Loss = 0.8333
# Epoch 1,/23400, Current Loss = 0.8988
# Epoch 1,/23500, Current Loss = 0.8594
# Epoch 1,/23600, Current Loss = 0.9827
# Epoch 1,/23700, Current Loss = 0.8211
# Epoch 1,/23800, Current Loss = 0.8773
# Epoch 1,/23900, Current Loss = 0.8686
# Epoch 1,/24000, Current Loss = 0.9401
# Epoch 1,/24100, Current Loss = 0.8812
# Epoch 1,/24200, Current Loss = 0.8831
# Epoch 1,/24300, Current Loss = 0.7660
# Epoch 1,/24400, Current Loss = 0.9021
# Epoch 1,/24500, Current Loss = 0.9131
# Epoch 1,/24600, Current Loss = 1.0177
# Epoch 1,/24700, Current Loss = 0.9288
# Epoch 1,/24800, Current Loss = 1.0119
# Epoch 1,/24900, Current Loss = 1.0418
# Epoch 1,/25000, Current Loss = 0.9603
# Epoch 1,/25100, Current Loss = 0.9471
# Epoch 1,/25200, Current Loss = 0.9157
# Epoch 1,/25300, Current Loss = 1.0296
# Epoch 1,/25400, Current Loss = 1.0739
# Epoch 1,/25500, Current Loss = 1.0222
# Epoch 1,/25600, Current Loss = 0.8292
# Epoch 1,/25700, Current Loss = 0.7895
# Epoch 1,/25800, Current Loss = 0.8754
# Epoch 1,/25900, Current Loss = 0.7794
# Epoch 1,/26000, Current Loss = 0.9900
# Epoch 1,/26100, Current Loss = 0.9187
# Epoch 1,/26200, Current Loss = 0.9744
# Epoch 1,/26300, Current Loss = 0.9011
# Epoch 1,/26400, Current Loss = 1.0498
# Epoch 1,/26500, Current Loss = 0.8131
# Epoch 1,/26600, Current Loss = 0.9395
# Epoch 1,/26700, Current Loss = 0.7386
# Epoch 1,/26800, Current Loss = 0.9225
# Epoch 1,/26900, Current Loss = 0.8139
# Epoch 1,/27000, Current Loss = 0.8356
# Epoch 1,/27100, Current Loss = 0.8223
# Epoch 1,/27200, Current Loss = 0.9296
# Epoch 1,/27300, Current Loss = 0.9063
# Epoch 1,/27400, Current Loss = 0.7973
# Epoch 1,/27500, Current Loss = 1.0238
# Epoch 1,/27600, Current Loss = 0.8541
# Epoch 1,/27700, Current Loss = 0.9549
# Epoch 1,/27800, Current Loss = 0.9572
# Epoch 1,/27900, Current Loss = 0.7578
# Epoch 1,/28000, Current Loss = 0.7719
# Epoch 1,/28100, Current Loss = 0.9953
# Epoch 1,/28200, Current Loss = 0.9835
# Epoch 1,/28300, Current Loss = 0.7662
# Epoch 1,/28400, Current Loss = 0.9415
# Epoch 1,/28500, Current Loss = 0.8110
# Epoch 1,/28600, Current Loss = 0.9273
# Epoch 1,/28700, Current Loss = 0.8668
# Epoch 1,/28800, Current Loss = 0.9126
# Epoch 1,/28900, Current Loss = 0.9690
# Epoch 1,/29000, Current Loss = 0.8858
# Epoch 1,/29100, Current Loss = 0.7322
# Epoch 1,/29200, Current Loss = 0.8233
# Epoch 1,/29300, Current Loss = 0.7795
# Epoch 1,/29400, Current Loss = 0.8985
# Epoch 1,/29500, Current Loss = 0.9197
# Epoch 1,/29600, Current Loss = 1.1258
# Epoch 1,/29700, Current Loss = 0.8717
# Epoch 1,/29800, Current Loss = 0.9242
# Epoch 1,/29900, Current Loss = 0.8284
# Epoch 1,/30000, Current Loss = 1.0224
# Epoch 1,/30100, Current Loss = 0.9576
# Epoch 1,/30200, Current Loss = 0.9636
# Epoch 1,/30300, Current Loss = 0.7795
# Epoch 1,/30400, Current Loss = 0.9709
# Epoch 1,/30500, Current Loss = 0.9438
# Epoch 1,/30600, Current Loss = 0.8955
# Epoch 1,/30700, Current Loss = 0.8178
# Epoch 1,/30800, Current Loss = 0.8750
# Epoch 1,/30900, Current Loss = 0.8385
# Epoch 1,/31000, Current Loss = 0.9406
# Epoch 1,/31100, Current Loss = 0.7585
# Epoch 1,/31200, Current Loss = 0.8383
# Epoch 1,/31300, Current Loss = 0.8137
# Epoch 1,/31400, Current Loss = 0.9213
# Epoch 1,/31500, Current Loss = 0.9611
# Epoch 1,/31600, Current Loss = 1.0087
# Epoch 1,/31700, Current Loss = 0.8757
# Epoch 1,/31800, Current Loss = 0.8864
# Epoch 1,/31900, Current Loss = 0.9482
# Epoch 1,/32000, Current Loss = 0.8583
# Epoch 1,/32100, Current Loss = 0.9086
# Epoch 1,/32200, Current Loss = 0.7586
# Epoch 1,/32300, Current Loss = 0.8916
# Epoch 1,/32400, Current Loss = 0.8657
# Epoch 1,/32500, Current Loss = 0.9315
# Epoch 1,/32600, Current Loss = 0.9439
# Epoch 1,/32700, Current Loss = 0.8613
# Epoch 1,/32800, Current Loss = 0.8275
# Epoch 1,/32900, Current Loss = 0.9503
# Epoch 1,/33000, Current Loss = 0.8555
# Epoch 1,/33100, Current Loss = 0.8277
# Epoch 1,/33200, Current Loss = 0.9673
# Epoch 1,/33300, Current Loss = 0.8002
# Epoch 1,/33400, Current Loss = 0.8012
# Epoch 1,/33500, Current Loss = 0.8417
# Epoch 1,/33600, Current Loss = 0.8016
# Epoch 1,/33700, Current Loss = 0.7986
# Epoch 1,/33800, Current Loss = 0.8833
# Epoch 1,/33900, Current Loss = 0.9538
# Epoch 1,/34000, Current Loss = 1.0639
# Epoch 1,/34100, Current Loss = 0.7997
# Epoch 1,/34200, Current Loss = 0.7837
# Epoch 1,/34300, Current Loss = 0.6970
# Epoch 1,/34400, Current Loss = 0.9198
# Epoch 1,/34500, Current Loss = 0.8483
# Epoch 1,/34600, Current Loss = 0.8511
# Epoch 1,/34700, Current Loss = 0.8612
# Epoch 1,/34800, Current Loss = 0.8288
# Epoch 1,/34900, Current Loss = 0.8073
# Epoch 1,/35000, Current Loss = 0.8433
# Epoch 1,/35100, Current Loss = 0.7836
# Epoch 1,/35200, Current Loss = 0.7781
# Epoch 1,/35300, Current Loss = 0.7019
# Epoch 1,/35400, Current Loss = 0.7679
# Epoch 1,/35500, Current Loss = 0.7903
# Epoch 1,/35600, Current Loss = 0.9783
# Epoch 1,/35700, Current Loss = 0.8246
# Epoch 1,/35800, Current Loss = 0.7707
# Epoch 1,/35900, Current Loss = 0.9609
# Epoch 1,/36000, Current Loss = 0.8214
# Epoch 1,/36100, Current Loss = 0.7328
# Epoch 1,/36200, Current Loss = 0.7948
# Epoch 1,/36300, Current Loss = 0.9479
# Epoch 1,/36400, Current Loss = 0.8173
# Epoch 1,/36500, Current Loss = 0.8713
# Epoch 1,/36600, Current Loss = 0.8385
# Epoch 1,/36700, Current Loss = 0.7358
# Epoch 1,/36800, Current Loss = 0.7429
# Epoch 1,/36900, Current Loss = 0.7926
# Epoch 1,/37000, Current Loss = 0.7674
# Epoch 1,/37100, Current Loss = 0.9991
# Epoch 1,/37200, Current Loss = 0.8311
# Epoch 1,/37300, Current Loss = 0.8763
# Epoch 1,/37400, Current Loss = 0.7325
# Epoch 1,/37500, Current Loss = 0.8224
# Epoch 1,/37600, Current Loss = 0.7673
# Epoch 1,/37700, Current Loss = 0.7546
# Epoch 1,/37800, Current Loss = 0.8953
# Epoch 1,/37900, Current Loss = 0.7013
# Epoch 1,/38000, Current Loss = 0.8564
# Epoch 1,/38100, Current Loss = 0.8644
# Epoch 1,/38200, Current Loss = 0.7555
# Epoch 1,/38300, Current Loss = 0.8071
# Epoch 1,/38400, Current Loss = 0.7156
# Epoch 1,/38500, Current Loss = 0.8757
# Epoch 1,/38600, Current Loss = 0.7999
# Epoch 1,/38700, Current Loss = 0.8884
# Epoch 1,/38800, Current Loss = 0.8413
# Epoch 1,/38900, Current Loss = 0.7553
# Epoch 1,/39000, Current Loss = 0.9096
# Epoch 1,/39100, Current Loss = 0.7770
# Epoch 1,/39200, Current Loss = 0.9285
# Epoch 1,/39300, Current Loss = 0.7609
# Epoch 1,/39400, Current Loss = 0.8441
# Epoch 1,/39500, Current Loss = 0.7598
# Epoch 1,/39600, Current Loss = 0.7348
# Epoch 1,/39700, Current Loss = 0.8449
# Epoch 1,/39800, Current Loss = 0.9272
# Epoch 1,/39900, Current Loss = 0.8662
# Epoch 1,/40000, Current Loss = 0.7889
# Epoch 1,/40100, Current Loss = 0.9806
# Epoch 1,/40200, Current Loss = 0.9732
# Epoch 1,/40300, Current Loss = 0.7310
# Epoch 1,/40400, Current Loss = 0.9024
# Epoch 1,/40500, Current Loss = 0.7326
# Epoch 1,/40600, Current Loss = 0.7523
# Epoch 1,/40700, Current Loss = 0.8450
# Epoch 1,/40800, Current Loss = 0.7612
# Epoch 1,/40900, Current Loss = 0.8034
# Epoch 1,/41000, Current Loss = 0.9702
# Epoch 1,/41100, Current Loss = 0.8977
# Epoch 1,/41200, Current Loss = 0.9402
# Epoch 1,/41300, Current Loss = 0.7828
# Epoch 1,/41400, Current Loss = 0.7455
# Epoch 1,/41500, Current Loss = 0.7044
# Epoch 1,/41600, Current Loss = 0.8640
# Epoch 1,/41700, Current Loss = 0.7092
# Epoch 1,/41800, Current Loss = 0.8061
# Epoch 1,/41900, Current Loss = 0.9028
# Epoch 1,/42000, Current Loss = 0.7365
# Epoch 1,/42100, Current Loss = 0.8897
# Epoch 1,/42200, Current Loss = 0.7725
# Epoch 1,/42300, Current Loss = 0.7299
# Epoch 1,/42400, Current Loss = 0.7850
# Epoch 1,/42500, Current Loss = 0.7284
# Epoch 1,/42600, Current Loss = 0.7467
# Epoch 1,/42700, Current Loss = 0.7762
# Epoch 1,/42800, Current Loss = 0.8695
# Epoch 1,/42900, Current Loss = 0.8503
# Epoch 1,/43000, Current Loss = 0.8789
# Epoch 1,/43100, Current Loss = 0.6691
# Epoch 1,/43200, Current Loss = 0.8815
# Epoch 1,/43300, Current Loss = 0.8869
# Epoch 1,/43400, Current Loss = 0.8126
# Epoch 1,/43500, Current Loss = 0.7616
# Epoch 1,/43600, Current Loss = 0.8407
# Epoch 1,/43700, Current Loss = 0.8144
# Epoch 1,/43800, Current Loss = 0.7947
# Epoch 1,/43900, Current Loss = 0.8610
# Epoch 1,/44000, Current Loss = 0.7877
# Epoch 1,/44100, Current Loss = 0.8714
# Epoch 1,/44200, Current Loss = 0.8170
# Epoch 1,/44300, Current Loss = 0.8267
# Epoch 1,/44400, Current Loss = 0.7441
# Epoch 1,/44500, Current Loss = 0.7567
# Epoch 1,/44600, Current Loss = 0.7797
# Epoch 1,/44700, Current Loss = 0.7248
# Epoch 1,/44800, Current Loss = 0.8445
# Epoch 1,/44900, Current Loss = 0.8158
# Epoch 1,/45000, Current Loss = 0.8723
# Epoch 1,/45100, Current Loss = 0.8671
# Epoch 1,/45200, Current Loss = 0.8281
# Epoch 1,/45300, Current Loss = 0.8560
# Epoch 1,/45400, Current Loss = 0.9671
# Epoch 1,/45500, Current Loss = 0.8024
# Epoch 1,/45600, Current Loss = 0.8318
# Epoch 1,/45700, Current Loss = 0.9045
# Epoch 1,/45800, Current Loss = 0.7963
# Epoch 1,/45900, Current Loss = 0.8446
# Epoch 1,/46000, Current Loss = 0.7422
# Epoch 1,/46100, Current Loss = 0.8414
# Epoch 1,/46200, Current Loss = 0.8569
# Epoch 1,/46300, Current Loss = 0.7964
# Epoch 1,/46400, Current Loss = 0.7116
# Epoch 1,/46500, Current Loss = 0.7987
# Epoch 1,/46600, Current Loss = 0.8172
# Epoch 1,/46700, Current Loss = 0.8475
# Epoch 1,/46800, Current Loss = 0.8539
# Epoch 1,/46900, Current Loss = 0.7983
# Epoch 1,/47000, Current Loss = 0.7625
# Epoch 1,/47100, Current Loss = 0.8552
# Epoch 1,/47200, Current Loss = 0.8412
# Epoch 1,/47300, Current Loss = 0.8147
# Epoch 1,/47400, Current Loss = 0.7619
# Epoch 1,/47500, Current Loss = 0.7694
# Epoch 1,/47600, Current Loss = 0.8708
# Epoch 1,/47700, Current Loss = 0.7482
# Epoch 1,/47800, Current Loss = 0.7989
# Epoch 1,/47900, Current Loss = 0.7700
# Epoch 1,/48000, Current Loss = 0.7562
# Epoch 1,/48100, Current Loss = 0.7783
# Epoch 1,/48200, Current Loss = 0.9080
# Epoch 1,/48300, Current Loss = 0.9213
# Epoch 1,/48400, Current Loss = 0.7464
# Epoch 1,/48500, Current Loss = 0.8300
# Epoch 1,/48600, Current Loss = 0.7968
# Epoch 1,/48700, Current Loss = 0.7247
# Epoch 1,/48800, Current Loss = 0.7652
# Epoch 1,/48900, Current Loss = 0.6733
# Epoch 1,/49000, Current Loss = 0.6653
# Epoch 1,/49100, Current Loss = 0.8129
# Epoch 1,/49200, Current Loss = 0.8557
# Epoch 1,/49300, Current Loss = 0.7841
# Epoch 1,/49400, Current Loss = 0.7778
# Epoch 1,/49500, Current Loss = 0.7432
# Epoch 1,/49600, Current Loss = 0.8288
# Epoch 1,/49700, Current Loss = 0.9004
# Epoch 1,/49800, Current Loss = 0.7423
# Epoch 1,/49900, Current Loss = 0.6918
# Epoch 1,/50000, Current Loss = 0.7564
# Epoch 1,/50100, Current Loss = 0.9007
# Epoch 1,/50200, Current Loss = 0.7948
# Epoch 1,/50300, Current Loss = 0.7473
# Epoch 1,/50400, Current Loss = 0.8301
# Epoch 1,/50500, Current Loss = 0.7879
# Epoch 1,/50600, Current Loss = 0.9730
# Epoch 1,/50700, Current Loss = 0.6710
# Epoch 1,/50800, Current Loss = 0.8428
# Epoch 1,/50900, Current Loss = 0.7421
# Epoch 1,/51000, Current Loss = 0.8899
# Epoch 1,/51100, Current Loss = 0.7847
# Epoch 1,/51200, Current Loss = 0.7969
# Epoch 1,/51300, Current Loss = 0.8309
# Epoch 1,/51400, Current Loss = 0.7091
# Epoch 1,/51500, Current Loss = 0.9225
# Epoch 1,/51600, Current Loss = 0.8727
# Epoch 1,/51700, Current Loss = 0.9051
# Epoch 1,/51800, Current Loss = 0.8084
# Epoch 1,/51900, Current Loss = 0.7980
# Epoch 1,/52000, Current Loss = 0.7079
# Epoch 1,/52100, Current Loss = 0.7767
# Epoch 1,/52200, Current Loss = 0.7825
# Epoch 1,/52300, Current Loss = 0.7726
# Epoch 1,/52400, Current Loss = 0.7728
# Epoch 1,/52500, Current Loss = 0.9190
# Epoch 1,/52600, Current Loss = 0.6439
# Epoch 1,/52700, Current Loss = 0.6659
# Epoch 1,/52800, Current Loss = 0.7532
# Epoch 1,/52900, Current Loss = 0.7735
# Epoch 1,/53000, Current Loss = 0.8386
# Epoch 1,/53100, Current Loss = 0.8780
# Epoch 1,/53200, Current Loss = 0.7987
# Epoch 1,/53300, Current Loss = 0.7716
# Epoch 1,/53400, Current Loss = 0.7488
# Epoch 1,/53500, Current Loss = 0.8401
# Epoch 1,/53600, Current Loss = 0.7297
# Epoch 1,/53700, Current Loss = 0.8505
# Epoch 1,/53800, Current Loss = 0.9385
# Epoch 1,/53900, Current Loss = 0.7165
# Epoch 1,/54000, Current Loss = 0.7512
# Epoch 1,/54100, Current Loss = 0.7692
# Epoch 1,/54200, Current Loss = 0.7192
# Epoch 1,/54300, Current Loss = 0.7648
# Epoch 1,/54400, Current Loss = 0.7113
# Epoch 1,/54500, Current Loss = 0.7968
# Epoch 1,/54600, Current Loss = 0.7610
# Epoch 1,/54700, Current Loss = 0.7132
# Epoch 1,/54800, Current Loss = 1.0062
# Epoch 1,/54900, Current Loss = 0.8264
# Epoch 1,/55000, Current Loss = 0.7255
# Epoch 1,/55100, Current Loss = 0.8340
# Epoch 1,/55200, Current Loss = 0.7754
# Epoch 1,/55300, Current Loss = 0.7342
# Epoch 1,/55400, Current Loss = 0.7516
# Epoch 1,/55500, Current Loss = 0.7528
# Epoch 1,/55600, Current Loss = 0.7562
# Epoch 1,/55700, Current Loss = 0.7662
# Epoch 1,/55800, Current Loss = 0.8808
# Epoch 1,/55900, Current Loss = 0.7624
# Epoch 1,/56000, Current Loss = 0.7453
# Epoch 1,/56100, Current Loss = 0.8551
# Epoch 1,/56200, Current Loss = 0.7182
# Epoch 1,/56300, Current Loss = 0.7984
# Epoch 1,/56400, Current Loss = 0.8832
# Epoch 1,/56500, Current Loss = 0.6806
# Epoch 1,/56600, Current Loss = 0.7772
# Epoch 1,/56700, Current Loss = 0.8431
# Epoch 1,/56800, Current Loss = 0.7121
# Epoch 1,/56900, Current Loss = 0.8122
# Epoch 1,/57000, Current Loss = 0.8023
# Epoch 1,/57100, Current Loss = 0.8042
# Epoch 1,/57200, Current Loss = 0.8302
# Epoch 1,/57300, Current Loss = 0.7606
# Epoch 1,/57400, Current Loss = 0.7075
# Epoch 1,/57500, Current Loss = 0.7146
# Epoch 1,/57600, Current Loss = 0.9391
# Epoch 1,/57700, Current Loss = 0.8580
# Epoch 1,/57800, Current Loss = 0.6090
# Epoch 1,/57900, Current Loss = 0.7661
# Epoch 1,/58000, Current Loss = 0.7909
# Epoch 1,/58100, Current Loss = 0.6873
# Epoch 1,/58200, Current Loss = 0.7882
# Epoch 1,/58300, Current Loss = 0.8129
# Epoch 1,/58400, Current Loss = 0.6468
# Epoch 1,/58500, Current Loss = 0.6379
# Epoch 1,/58600, Current Loss = 0.7182
# Epoch 1,/58700, Current Loss = 0.7733
# Epoch 1,/58800, Current Loss = 0.7987
# Epoch 1,/58900, Current Loss = 0.7736
# Epoch 1,/59000, Current Loss = 0.8127
# Epoch 1,/59100, Current Loss = 0.9460
# Epoch 1,/59200, Current Loss = 0.7955
# Epoch 1,/59300, Current Loss = 0.7145
# Epoch 1,/59400, Current Loss = 0.6790
# Epoch 1,/59500, Current Loss = 0.6992
# Epoch 1,/59600, Current Loss = 0.8300
# Epoch 1,/59700, Current Loss = 0.7262
# Epoch 1,/59800, Current Loss = 0.7895
# Epoch 1,/59900, Current Loss = 0.8056
# Epoch 1,/60000, Current Loss = 0.9303
# Epoch 1,/60100, Current Loss = 0.8170
# Epoch 1,/60200, Current Loss = 0.6750
# Epoch 1,/60300, Current Loss = 0.8035
# Epoch 1,/60400, Current Loss = 0.7172
# Epoch 1,/60500, Current Loss = 0.7051
# Epoch 1,/60600, Current Loss = 0.7276
# Epoch 1,/60700, Current Loss = 0.6226
# Epoch 1,/60800, Current Loss = 0.8035
# Epoch 1,/60900, Current Loss = 0.7097
# Epoch 1,/61000, Current Loss = 0.5834
# Epoch 1,/61100, Current Loss = 0.9617
# Epoch 1,/61200, Current Loss = 0.7867
# Epoch 1,/61300, Current Loss = 0.7130
# Epoch 1,/61400, Current Loss = 0.8520
# Epoch 1,/61500, Current Loss = 0.7615
# Epoch 1,/61600, Current Loss = 0.8075
# Epoch 1,/61700, Current Loss = 0.6721
# Epoch 1,/61800, Current Loss = 0.7277
# Epoch 1,/61900, Current Loss = 0.9184
# Epoch 1,/62000, Current Loss = 0.8066
# Epoch 1,/62100, Current Loss = 0.7342
# Epoch 1,/62200, Current Loss = 0.7588
# Epoch 1,/62300, Current Loss = 0.8455
# Epoch 1,/62400, Current Loss = 0.7131
# Epoch 1,/62500, Current Loss = 0.7182
# Epoch 1,/62600, Current Loss = 0.7673
# Epoch 1,/62700, Current Loss = 0.7719
# Epoch 1,/62800, Current Loss = 0.7422
# Epoch 1,/62900, Current Loss = 0.7380
# Epoch 1,/63000, Current Loss = 0.6708
# Epoch 1,/63100, Current Loss = 0.8240
# Epoch 1,/63200, Current Loss = 0.7435
# Epoch 1,/63300, Current Loss = 0.7173
# Epoch 1,/63400, Current Loss = 0.7290
# Epoch 1,/63500, Current Loss = 0.9167
# Epoch 1,/63600, Current Loss = 0.7248
# Epoch 1,/63700, Current Loss = 0.7687
# Epoch 1,/63800, Current Loss = 0.7253
# Epoch 1,/63900, Current Loss = 0.8689
# Epoch 1,/64000, Current Loss = 0.7437
# Epoch 1,/64100, Current Loss = 0.8082
# Epoch 1,/64200, Current Loss = 0.5678
# Epoch 1,/64300, Current Loss = 0.6550
# Epoch 1,/64400, Current Loss = 0.8608
# Epoch 1,/64500, Current Loss = 0.6628
# Epoch 1,/64600, Current Loss = 0.7339
# Epoch 1,/64700, Current Loss = 0.6518
# Epoch 1,/64800, Current Loss = 0.7539
# Epoch 1,/64900, Current Loss = 0.7579
# Epoch 1,/65000, Current Loss = 0.7642
# Epoch 1,/65100, Current Loss = 0.9180
# Epoch 1,/65200, Current Loss = 0.7547
# Epoch 1,/65300, Current Loss = 0.7473
# Epoch 1,/65400, Current Loss = 0.8215
# Epoch 1,/65500, Current Loss = 0.8800
# Epoch 1,/65600, Current Loss = 0.6830
# Epoch 1,/65700, Current Loss = 0.7023
# Epoch 1,/65800, Current Loss = 0.5967
# Epoch 1,/65900, Current Loss = 0.8308
# Epoch 1,/66000, Current Loss = 0.7401
# Epoch 1,/66100, Current Loss = 0.7445
# Epoch 1,/66200, Current Loss = 0.6703
# Epoch 1,/66300, Current Loss = 0.8098
# Epoch 1,/66400, Current Loss = 0.8120
# Epoch 1,/66500, Current Loss = 0.8015
# Epoch 1,/66600, Current Loss = 0.8010
# Epoch 1,/66700, Current Loss = 0.8465
# Epoch 1,/66800, Current Loss = 0.8740
# Epoch 1,/66900, Current Loss = 0.8231
# Epoch 1,/67000, Current Loss = 0.7807
# Epoch 1,/67100, Current Loss = 0.7345
# Epoch 1,/67200, Current Loss = 0.7396
# Epoch 1,/67300, Current Loss = 0.7723
# Epoch 1,/67400, Current Loss = 0.7233
# Epoch 1,/67500, Current Loss = 0.7291
# Epoch 1,/67600, Current Loss = 0.7077
# Epoch 1,/67700, Current Loss = 0.6449
# Epoch 1,/67800, Current Loss = 0.7463
# Epoch 1,/67900, Current Loss = 0.7282
# Epoch 1,/68000, Current Loss = 0.7290
# Epoch 1,/68100, Current Loss = 0.7519
# Epoch 1,/68200, Current Loss = 0.8584
# Epoch 1,/68300, Current Loss = 0.7845
# Epoch 1,/68400, Current Loss = 0.7691
# Epoch 1,/68500, Current Loss = 0.6477
# Epoch 1,/68600, Current Loss = 0.6415
# Epoch 1,/68700, Current Loss = 0.6783
# Epoch 1,/68800, Current Loss = 0.7533
# Epoch 1,/68900, Current Loss = 0.7465
# Epoch 1,/69000, Current Loss = 0.6751
# Epoch 1,/69100, Current Loss = 0.6809
# Epoch 1,/69200, Current Loss = 0.7597
# Epoch 1,/69300, Current Loss = 0.7830
# Epoch 1,/69400, Current Loss = 0.6551
# Epoch 1,/69500, Current Loss = 0.7678
# Epoch 1,/69600, Current Loss = 0.8500
# Epoch 1,/69700, Current Loss = 0.8703
# Epoch 1,/69800, Current Loss = 0.8163
# Epoch 1,/69900, Current Loss = 0.7754
# Epoch 1,/70000, Current Loss = 0.7386
# Epoch 1,/70100, Current Loss = 0.6320
# Epoch 1,/70200, Current Loss = 0.7424
# Epoch 1,/70300, Current Loss = 0.6698
# Epoch 1,/70400, Current Loss = 0.8493
# Epoch 1,/70500, Current Loss = 0.7246
# Epoch 1,/70600, Current Loss = 0.7900
# Epoch 1,/70700, Current Loss = 0.6900
# Epoch 1,/70800, Current Loss = 0.6998
# Epoch 1,/70900, Current Loss = 0.7154
# Epoch 1,/71000, Current Loss = 0.7564
# Epoch 1,/71100, Current Loss = 0.8755
# Epoch 1,/71200, Current Loss = 0.7525
# Epoch 1,/71300, Current Loss = 0.7496
# Epoch 1,/71400, Current Loss = 0.7022
# Epoch 1,/71500, Current Loss = 0.8123
# Epoch 1,/71600, Current Loss = 0.7626
# Epoch 1,/71700, Current Loss = 0.7478
# Epoch 1,/71800, Current Loss = 0.7270
# Epoch 1,/71900, Current Loss = 0.7292
# Epoch 1,/72000, Current Loss = 0.7447
# Epoch 1,/72100, Current Loss = 0.8109
# Epoch 1,/72200, Current Loss = 0.7943
# Epoch 1,/72300, Current Loss = 0.7919
# Epoch 1,/72400, Current Loss = 0.6745
# Epoch 1,/72500, Current Loss = 0.7769
# Epoch 1,/72600, Current Loss = 0.7083
# Epoch 1,/72700, Current Loss = 0.8326
# Epoch 1,/72800, Current Loss = 0.7360
# Epoch 1,/72900, Current Loss = 0.7607
# Epoch 1,/73000, Current Loss = 0.8286
# Epoch 1,/73100, Current Loss = 0.6293
# Epoch 1,/73200, Current Loss = 0.6872
# Epoch 1,/73300, Current Loss = 0.8258
# Epoch 1,/73400, Current Loss = 0.7843
# Epoch 1,/73500, Current Loss = 0.7067
# Epoch 1,/73600, Current Loss = 0.7467
# Epoch 1,/73700, Current Loss = 0.7178
# Epoch 1,/73800, Current Loss = 0.6098
# Epoch 1,/73900, Current Loss = 0.8244
# Epoch 1,/74000, Current Loss = 0.7526
# Epoch 1,/74100, Current Loss = 0.7304
# Epoch 1,/74200, Current Loss = 0.6651
# Epoch 1,/74300, Current Loss = 0.6462
# Epoch 1,/74400, Current Loss = 0.8254
# Epoch 1,/74500, Current Loss = 0.7147
# Epoch 1,/74600, Current Loss = 0.5883
# Epoch 1,/74700, Current Loss = 0.6676
# Epoch 1,/74800, Current Loss = 0.6170
# Epoch 1,/74900, Current Loss = 0.6623
# Epoch 1,/75000, Current Loss = 0.7482
# Epoch 1,/75100, Current Loss = 0.7663
# Epoch 1,/75200, Current Loss = 0.7075
# Epoch 1,/75300, Current Loss = 0.7274
# Epoch 1,/75400, Current Loss = 0.7498
# Epoch 1,/75500, Current Loss = 0.7377
# Epoch 1,/75600, Current Loss = 0.6794
# Epoch 1,/75700, Current Loss = 0.7861
# Epoch 1,/75800, Current Loss = 0.7584
# Epoch 1,/75900, Current Loss = 0.7464
# Epoch 1,/76000, Current Loss = 0.6274
# Epoch 1,/76100, Current Loss = 0.7496
# Epoch 1,/76200, Current Loss = 0.7223
# Epoch 1,/76300, Current Loss = 0.7553
# Epoch 1,/76400, Current Loss = 0.7573
# Epoch 1,/76500, Current Loss = 0.6397
# Epoch 1,/76600, Current Loss = 0.7953
# Epoch 1,/76700, Current Loss = 0.6093
# Epoch 1,/76800, Current Loss = 0.7553
# Epoch 1,/76900, Current Loss = 0.7105
# Epoch 1,/77000, Current Loss = 0.7998
# Epoch 1,/77100, Current Loss = 0.8615
# Epoch 1,/77200, Current Loss = 0.8274
# Epoch 1,/77300, Current Loss = 0.6547
# Epoch 1,/77400, Current Loss = 0.7634
# Epoch 1,/77500, Current Loss = 0.7666
# Epoch 1,/77600, Current Loss = 0.8045
# Epoch 1,/77700, Current Loss = 0.6889
# Epoch 1,/77800, Current Loss = 0.7748
# Epoch 1,/77900, Current Loss = 0.7030
# Epoch 1,/78000, Current Loss = 0.6796
# Epoch 2,/100, Current Loss = 0.7175
# Epoch 2,/200, Current Loss = 0.7685
# Epoch 2,/300, Current Loss = 0.9147
# Epoch 2,/400, Current Loss = 0.7179
# Epoch 2,/500, Current Loss = 0.8402
# Epoch 2,/600, Current Loss = 0.7771
# Epoch 2,/700, Current Loss = 0.7430
# Epoch 2,/800, Current Loss = 0.7111
# Epoch 2,/900, Current Loss = 0.7674
# Epoch 2,/1000, Current Loss = 0.7976
# Epoch 2,/1100, Current Loss = 0.6548
# Epoch 2,/1200, Current Loss = 0.6703
# Epoch 2,/1300, Current Loss = 0.5640
# Epoch 2,/1400, Current Loss = 0.6877
# Epoch 2,/1500, Current Loss = 0.9029
# Epoch 2,/1600, Current Loss = 0.6769
# Epoch 2,/1700, Current Loss = 0.8388
# Epoch 2,/1800, Current Loss = 0.7046
# Epoch 2,/1900, Current Loss = 0.7621
# Epoch 2,/2000, Current Loss = 0.7292
# Epoch 2,/2100, Current Loss = 0.7490
# Epoch 2,/2200, Current Loss = 0.7603
# Epoch 2,/2300, Current Loss = 0.7590
# Epoch 2,/2400, Current Loss = 0.6971
# Epoch 2,/2500, Current Loss = 0.6536
# Epoch 2,/2600, Current Loss = 0.8330
# Epoch 2,/2700, Current Loss = 0.5773
# Epoch 2,/2800, Current Loss = 0.6843
# Epoch 2,/2900, Current Loss = 0.7755
# Epoch 2,/3000, Current Loss = 0.7864
# Epoch 2,/3100, Current Loss = 0.7642
# Epoch 2,/3200, Current Loss = 0.8186
# Epoch 2,/3300, Current Loss = 0.5848
# Epoch 2,/3400, Current Loss = 0.6251
# Epoch 2,/3500, Current Loss = 0.5980
# Epoch 2,/3600, Current Loss = 0.7342
# Epoch 2,/3700, Current Loss = 0.7870
# Epoch 2,/3800, Current Loss = 0.7766
# Epoch 2,/3900, Current Loss = 0.7958
# Epoch 2,/4000, Current Loss = 0.7770
# Epoch 2,/4100, Current Loss = 0.7233
# Epoch 2,/4200, Current Loss = 0.8306
# Epoch 2,/4300, Current Loss = 0.7436
# Epoch 2,/4400, Current Loss = 0.7846
# Epoch 2,/4500, Current Loss = 0.7882
# Epoch 2,/4600, Current Loss = 0.7835
# Epoch 2,/4700, Current Loss = 0.6491
# Epoch 2,/4800, Current Loss = 0.7111
# Epoch 2,/4900, Current Loss = 0.8129
# Epoch 2,/5000, Current Loss = 0.8433
# Epoch 2,/5100, Current Loss = 0.7833
# Epoch 2,/5200, Current Loss = 0.7639
# Epoch 2,/5300, Current Loss = 0.6228
# Epoch 2,/5400, Current Loss = 0.7919
# Epoch 2,/5500, Current Loss = 0.7758
# Epoch 2,/5600, Current Loss = 0.6635
# Epoch 2,/5700, Current Loss = 0.6631
# Epoch 2,/5800, Current Loss = 0.6984
# Epoch 2,/5900, Current Loss = 0.6971
# Epoch 2,/6000, Current Loss = 0.6581
# Epoch 2,/6100, Current Loss = 0.8640
# Epoch 2,/6200, Current Loss = 0.8064
# Epoch 2,/6300, Current Loss = 0.6896
# Epoch 2,/6400, Current Loss = 0.7398
# Epoch 2,/6500, Current Loss = 0.8043
# Epoch 2,/6600, Current Loss = 0.8571
# Epoch 2,/6700, Current Loss = 0.7183
# Epoch 2,/6800, Current Loss = 0.7444
# Epoch 2,/6900, Current Loss = 0.8027
# Epoch 2,/7000, Current Loss = 0.7351
# Epoch 2,/7100, Current Loss = 0.7563
# Epoch 2,/7200, Current Loss = 0.7772
# Epoch 2,/7300, Current Loss = 0.6462
# Epoch 2,/7400, Current Loss = 0.8110
# Epoch 2,/7500, Current Loss = 0.6451
# Epoch 2,/7600, Current Loss = 0.8052
# Epoch 2,/7700, Current Loss = 0.7332
# Epoch 2,/7800, Current Loss = 0.6812
# Epoch 2,/7900, Current Loss = 0.6771
# Epoch 2,/8000, Current Loss = 0.7162
# Epoch 2,/8100, Current Loss = 0.7422
# Epoch 2,/8200, Current Loss = 0.7314
# Epoch 2,/8300, Current Loss = 0.8116
# Epoch 2,/8400, Current Loss = 0.6797
# Epoch 2,/8500, Current Loss = 0.8084
# Epoch 2,/8600, Current Loss = 0.6666
# Epoch 2,/8700, Current Loss = 0.6524
# Epoch 2,/8800, Current Loss = 0.6487
# Epoch 2,/8900, Current Loss = 0.6834
# Epoch 2,/9000, Current Loss = 0.7218
# Epoch 2,/9100, Current Loss = 0.8784
# Epoch 2,/9200, Current Loss = 0.6222
# Epoch 2,/9300, Current Loss = 0.6294
# Epoch 2,/9400, Current Loss = 0.7594
# Epoch 2,/9500, Current Loss = 0.8048
# Epoch 2,/9600, Current Loss = 0.8749
# Epoch 2,/9700, Current Loss = 0.7177
# Epoch 2,/9800, Current Loss = 0.7840
# Epoch 2,/9900, Current Loss = 0.6617
# Epoch 2,/10000, Current Loss = 0.8155
# Epoch 2,/10100, Current Loss = 0.8048
# Epoch 2,/10200, Current Loss = 0.7106
# Epoch 2,/10300, Current Loss = 0.9302
# Epoch 2,/10400, Current Loss = 0.7480
# Epoch 2,/10500, Current Loss = 0.8247
# Epoch 2,/10600, Current Loss = 0.8177
# Epoch 2,/10700, Current Loss = 0.7805
# Epoch 2,/10800, Current Loss = 0.7237
# Epoch 2,/10900, Current Loss = 0.9088
# Epoch 2,/11000, Current Loss = 0.7314
# Epoch 2,/11100, Current Loss = 0.7599
# Epoch 2,/11200, Current Loss = 0.8177
# Epoch 2,/11300, Current Loss = 0.7350
# Epoch 2,/11400, Current Loss = 0.8491
# Epoch 2,/11500, Current Loss = 0.6947
# Epoch 2,/11600, Current Loss = 0.6664
# Epoch 2,/11700, Current Loss = 0.7657
# Epoch 2,/11800, Current Loss = 0.6651
# Epoch 2,/11900, Current Loss = 0.6775
# Epoch 2,/12000, Current Loss = 0.7385
# Epoch 2,/12100, Current Loss = 0.6570
# Epoch 2,/12200, Current Loss = 0.6804
# Epoch 2,/12300, Current Loss = 0.7376
# Epoch 2,/12400, Current Loss = 0.8017
# Epoch 2,/12500, Current Loss = 0.8266
# Epoch 2,/12600, Current Loss = 0.7138
# Epoch 2,/12700, Current Loss = 0.6491
# Epoch 2,/12800, Current Loss = 0.7175
# Epoch 2,/12900, Current Loss = 0.8586
# Epoch 2,/13000, Current Loss = 0.6536
# Epoch 2,/13100, Current Loss = 0.7331
# Epoch 2,/13200, Current Loss = 0.5766
# Epoch 2,/13300, Current Loss = 0.7756
# Epoch 2,/13400, Current Loss = 0.6859
# Epoch 2,/13500, Current Loss = 0.8190
# Epoch 2,/13600, Current Loss = 0.7566
# Epoch 2,/13700, Current Loss = 0.7916
# Epoch 2,/13800, Current Loss = 0.8406
# Epoch 2,/13900, Current Loss = 0.8228
# Epoch 2,/14000, Current Loss = 0.6527
# Epoch 2,/14100, Current Loss = 0.7206
# Epoch 2,/14200, Current Loss = 0.6911
# Epoch 2,/14300, Current Loss = 0.7648
# Epoch 2,/14400, Current Loss = 0.6983
# Epoch 2,/14500, Current Loss = 0.7097
# Epoch 2,/14600, Current Loss = 0.6189
# Epoch 2,/14700, Current Loss = 0.9073
# Epoch 2,/14800, Current Loss = 0.7353
# Epoch 2,/14900, Current Loss = 0.7427
# Epoch 2,/15000, Current Loss = 0.7699
# Epoch 2,/15100, Current Loss = 0.8499
# Epoch 2,/15200, Current Loss = 0.7734
# Epoch 2,/15300, Current Loss = 0.8839
# Epoch 2,/15400, Current Loss = 0.8023
# Epoch 2,/15500, Current Loss = 0.8291
# Epoch 2,/15600, Current Loss = 0.7241
# Epoch 2,/15700, Current Loss = 0.6162
# Epoch 2,/15800, Current Loss = 0.7348
# Epoch 2,/15900, Current Loss = 0.7436
# Epoch 2,/16000, Current Loss = 0.7490
# Epoch 2,/16100, Current Loss = 0.8166
# Epoch 2,/16200, Current Loss = 0.6839
# Epoch 2,/16300, Current Loss = 0.6622
# Epoch 2,/16400, Current Loss = 0.7575
# Epoch 2,/16500, Current Loss = 0.7125
# Epoch 2,/16600, Current Loss = 0.6893
# Epoch 2,/16700, Current Loss = 0.6014
# Epoch 2,/16800, Current Loss = 0.7759
# Epoch 2,/16900, Current Loss = 0.7437
# Epoch 2,/17000, Current Loss = 0.6536
# Epoch 2,/17100, Current Loss = 0.6231
# Epoch 2,/17200, Current Loss = 0.7042
# Epoch 2,/17300, Current Loss = 0.8332
# Epoch 2,/17400, Current Loss = 0.6681
# Epoch 2,/17500, Current Loss = 0.6667
# Epoch 2,/17600, Current Loss = 0.7301
# Epoch 2,/17700, Current Loss = 0.7420
# Epoch 2,/17800, Current Loss = 0.7719
# Epoch 2,/17900, Current Loss = 0.7500
# Epoch 2,/18000, Current Loss = 0.7182
# Epoch 2,/18100, Current Loss = 0.7418
# Epoch 2,/18200, Current Loss = 0.5842
# Epoch 2,/18300, Current Loss = 0.7412
# Epoch 2,/18400, Current Loss = 0.7139
# Epoch 2,/18500, Current Loss = 0.7825
# Epoch 2,/18600, Current Loss = 0.7172
# Epoch 2,/18700, Current Loss = 0.6851
# Epoch 2,/18800, Current Loss = 0.7565
# Epoch 2,/18900, Current Loss = 0.7718
# Epoch 2,/19000, Current Loss = 0.8627
# Epoch 2,/19100, Current Loss = 0.6441
# Epoch 2,/19200, Current Loss = 0.7403
# Epoch 2,/19300, Current Loss = 0.6927
# Epoch 2,/19400, Current Loss = 0.7266
# Epoch 2,/19500, Current Loss = 0.6859
# Epoch 2,/19600, Current Loss = 0.6430
# Epoch 2,/19700, Current Loss = 0.6919
# Epoch 2,/19800, Current Loss = 0.8319
# Epoch 2,/19900, Current Loss = 0.6115
# Epoch 2,/20000, Current Loss = 0.5899
# Epoch 2,/20100, Current Loss = 0.5536
# Epoch 2,/20200, Current Loss = 0.7510
# Epoch 2,/20300, Current Loss = 0.7269
# Epoch 2,/20400, Current Loss = 0.7206
# Epoch 2,/20500, Current Loss = 0.8376
# Epoch 2,/20600, Current Loss = 0.6776
# Epoch 2,/20700, Current Loss = 0.7081
# Epoch 2,/20800, Current Loss = 0.6713
# Epoch 2,/20900, Current Loss = 0.7510
# Epoch 2,/21000, Current Loss = 0.6927
# Epoch 2,/21100, Current Loss = 0.7014
# Epoch 2,/21200, Current Loss = 0.6002
# Epoch 2,/21300, Current Loss = 0.7089
# Epoch 2,/21400, Current Loss = 0.7450
# Epoch 2,/21500, Current Loss = 0.7107
# Epoch 2,/21600, Current Loss = 0.6172
# Epoch 2,/21700, Current Loss = 0.7970
# Epoch 2,/21800, Current Loss = 0.6238
# Epoch 2,/21900, Current Loss = 0.7079
# Epoch 2,/22000, Current Loss = 0.6841
# Epoch 2,/22100, Current Loss = 0.6801
# Epoch 2,/22200, Current Loss = 0.7006
# Epoch 2,/22300, Current Loss = 0.6887
# Epoch 2,/22400, Current Loss = 0.6982
# Epoch 2,/22500, Current Loss = 0.6146
# Epoch 2,/22600, Current Loss = 0.6743
# Epoch 2,/22700, Current Loss = 0.8361
# Epoch 2,/22800, Current Loss = 0.6512
# Epoch 2,/22900, Current Loss = 0.7848
# Epoch 2,/23000, Current Loss = 0.7237
# Epoch 2,/23100, Current Loss = 0.7698
# Epoch 2,/23200, Current Loss = 0.7687
# Epoch 2,/23300, Current Loss = 0.6468
# Epoch 2,/23400, Current Loss = 0.7208
# Epoch 2,/23500, Current Loss = 0.7162
# Epoch 2,/23600, Current Loss = 0.7587
# Epoch 2,/23700, Current Loss = 0.6660
# Epoch 2,/23800, Current Loss = 0.6141
# Epoch 2,/23900, Current Loss = 0.6962
# Epoch 2,/24000, Current Loss = 0.7789
# Epoch 2,/24100, Current Loss = 0.7309
# Epoch 2,/24200, Current Loss = 0.6623
# Epoch 2,/24300, Current Loss = 0.5425
# Epoch 2,/24400, Current Loss = 0.7642
# Epoch 2,/24500, Current Loss = 0.7212
# Epoch 2,/24600, Current Loss = 0.8200
# Epoch 2,/24700, Current Loss = 0.7464
# Epoch 2,/24800, Current Loss = 0.8533
# Epoch 2,/24900, Current Loss = 0.8870
# Epoch 2,/25000, Current Loss = 0.7877
# Epoch 2,/25100, Current Loss = 0.7750
# Epoch 2,/25200, Current Loss = 0.8012
# Epoch 2,/25300, Current Loss = 0.8454
# Epoch 2,/25400, Current Loss = 0.8486
# Epoch 2,/25500, Current Loss = 0.8461
# Epoch 2,/25600, Current Loss = 0.6624
# Epoch 2,/25700, Current Loss = 0.6601
# Epoch 2,/25800, Current Loss = 0.6801
# Epoch 2,/25900, Current Loss = 0.6144
# Epoch 2,/26000, Current Loss = 0.8128
# Epoch 2,/26100, Current Loss = 0.7847
# Epoch 2,/26200, Current Loss = 0.7902
# Epoch 2,/26300, Current Loss = 0.7213
# Epoch 2,/26400, Current Loss = 0.8951
# Epoch 2,/26500, Current Loss = 0.6703
# Epoch 2,/26600, Current Loss = 0.8165
# Epoch 2,/26700, Current Loss = 0.6037
# Epoch 2,/26800, Current Loss = 0.7400
# Epoch 2,/26900, Current Loss = 0.6318
# Epoch 2,/27000, Current Loss = 0.6715
# Epoch 2,/27100, Current Loss = 0.6112
# Epoch 2,/27200, Current Loss = 0.7832
# Epoch 2,/27300, Current Loss = 0.7257
# Epoch 2,/27400, Current Loss = 0.6872
# Epoch 2,/27500, Current Loss = 0.8176
# Epoch 2,/27600, Current Loss = 0.7311
# Epoch 2,/27700, Current Loss = 0.8022
# Epoch 2,/27800, Current Loss = 0.7992
# Epoch 2,/27900, Current Loss = 0.5983
# Epoch 2,/28000, Current Loss = 0.6008
# Epoch 2,/28100, Current Loss = 0.8220
# Epoch 2,/28200, Current Loss = 0.8175
# Epoch 2,/28300, Current Loss = 0.6563
# Epoch 2,/28400, Current Loss = 0.8024
# Epoch 2,/28500, Current Loss = 0.6981
# Epoch 2,/28600, Current Loss = 0.7698
# Epoch 2,/28700, Current Loss = 0.6942
# Epoch 2,/28800, Current Loss = 0.7738
# Epoch 2,/28900, Current Loss = 0.7952
# Epoch 2,/29000, Current Loss = 0.7617
# Epoch 2,/29100, Current Loss = 0.6017
# Epoch 2,/29200, Current Loss = 0.6817
# Epoch 2,/29300, Current Loss = 0.6236
# Epoch 2,/29400, Current Loss = 0.7574
# Epoch 2,/29500, Current Loss = 0.7680
# Epoch 2,/29600, Current Loss = 0.9775
# Epoch 2,/29700, Current Loss = 0.7232
# Epoch 2,/29800, Current Loss = 0.7708
# Epoch 2,/29900, Current Loss = 0.6897
# Epoch 2,/30000, Current Loss = 0.8428
# Epoch 2,/30100, Current Loss = 0.8015
# Epoch 2,/30200, Current Loss = 0.8203
# Epoch 2,/30300, Current Loss = 0.6417
# Epoch 2,/30400, Current Loss = 0.8487
# Epoch 2,/30500, Current Loss = 0.8202
# Epoch 2,/30600, Current Loss = 0.7043
# Epoch 2,/30700, Current Loss = 0.7030
# Epoch 2,/30800, Current Loss = 0.7383
# Epoch 2,/30900, Current Loss = 0.6976
# Epoch 2,/31000, Current Loss = 0.7780
# Epoch 2,/31100, Current Loss = 0.5761
# Epoch 2,/31200, Current Loss = 0.7087
# Epoch 2,/31300, Current Loss = 0.6837
# Epoch 2,/31400, Current Loss = 0.8076
# Epoch 2,/31500, Current Loss = 0.8002
# Epoch 2,/31600, Current Loss = 0.8963
# Epoch 2,/31700, Current Loss = 0.7248
# Epoch 2,/31800, Current Loss = 0.7033
# Epoch 2,/31900, Current Loss = 0.8116
# Epoch 2,/32000, Current Loss = 0.6955
# Epoch 2,/32100, Current Loss = 0.7567
# Epoch 2,/32200, Current Loss = 0.6304
# Epoch 2,/32300, Current Loss = 0.7660
# Epoch 2,/32400, Current Loss = 0.6975
# Epoch 2,/32500, Current Loss = 0.7826
# Epoch 2,/32600, Current Loss = 0.7942
# Epoch 2,/32700, Current Loss = 0.7692
# Epoch 2,/32800, Current Loss = 0.7281
# Epoch 2,/32900, Current Loss = 0.8011
# Epoch 2,/33000, Current Loss = 0.7196
# Epoch 2,/33100, Current Loss = 0.6841
# Epoch 2,/33200, Current Loss = 0.7868
# Epoch 2,/33300, Current Loss = 0.6869
# Epoch 2,/33400, Current Loss = 0.6871
# Epoch 2,/33500, Current Loss = 0.7293
# Epoch 2,/33600, Current Loss = 0.6696
# Epoch 2,/33700, Current Loss = 0.6646
# Epoch 2,/33800, Current Loss = 0.7736
# Epoch 2,/33900, Current Loss = 0.8106
# Epoch 2,/34000, Current Loss = 0.8993
# Epoch 2,/34100, Current Loss = 0.6532
# Epoch 2,/34200, Current Loss = 0.6544
# Epoch 2,/34300, Current Loss = 0.6068
# Epoch 2,/34400, Current Loss = 0.7574
# Epoch 2,/34500, Current Loss = 0.7457
# Epoch 2,/34600, Current Loss = 0.6985
# Epoch 2,/34700, Current Loss = 0.7418
# Epoch 2,/34800, Current Loss = 0.6995
# Epoch 2,/34900, Current Loss = 0.6622
# Epoch 2,/35000, Current Loss = 0.7486
# Epoch 2,/35100, Current Loss = 0.6477
# Epoch 2,/35200, Current Loss = 0.6541
# Epoch 2,/35300, Current Loss = 0.5933
# Epoch 2,/35400, Current Loss = 0.5973
# Epoch 2,/35500, Current Loss = 0.6569
# Epoch 2,/35600, Current Loss = 0.8520
# Epoch 2,/35700, Current Loss = 0.7027
# Epoch 2,/35800, Current Loss = 0.6075
# Epoch 2,/35900, Current Loss = 0.8477
# Epoch 2,/36000, Current Loss = 0.7176
# Epoch 2,/36100, Current Loss = 0.6134
# Epoch 2,/36200, Current Loss = 0.7033
# Epoch 2,/36300, Current Loss = 0.8100
# Epoch 2,/36400, Current Loss = 0.6677
# Epoch 2,/36500, Current Loss = 0.7397
# Epoch 2,/36600, Current Loss = 0.7126
# Epoch 2,/36700, Current Loss = 0.6141
# Epoch 2,/36800, Current Loss = 0.6408
# Epoch 2,/36900, Current Loss = 0.6720
# Epoch 2,/37000, Current Loss = 0.6445
# Epoch 2,/37100, Current Loss = 0.8830
# Epoch 2,/37200, Current Loss = 0.7314
# Epoch 2,/37300, Current Loss = 0.7169
# Epoch 2,/37400, Current Loss = 0.5982
# Epoch 2,/37500, Current Loss = 0.7118
# Epoch 2,/37600, Current Loss = 0.6539
# Epoch 2,/37700, Current Loss = 0.6331
# Epoch 2,/37800, Current Loss = 0.7725
# Epoch 2,/37900, Current Loss = 0.5675
# Epoch 2,/38000, Current Loss = 0.7525
# Epoch 2,/38100, Current Loss = 0.7211
# Epoch 2,/38200, Current Loss = 0.6287
# Epoch 2,/38300, Current Loss = 0.7191
# Epoch 2,/38400, Current Loss = 0.6188
# Epoch 2,/38500, Current Loss = 0.7787
# Epoch 2,/38600, Current Loss = 0.7098
# Epoch 2,/38700, Current Loss = 0.7830
# Epoch 2,/38800, Current Loss = 0.7196
# Epoch 2,/38900, Current Loss = 0.6423
# Epoch 2,/39000, Current Loss = 0.7841
# Epoch 2,/39100, Current Loss = 0.6917
# Epoch 2,/39200, Current Loss = 0.8016
# Epoch 2,/39300, Current Loss = 0.6151
# Epoch 2,/39400, Current Loss = 0.7150
# Epoch 2,/39500, Current Loss = 0.6148
# Epoch 2,/39600, Current Loss = 0.5879
# Epoch 2,/39700, Current Loss = 0.7330
# Epoch 2,/39800, Current Loss = 0.8145
# Epoch 2,/39900, Current Loss = 0.7501
# Epoch 2,/40000, Current Loss = 0.6715
# Epoch 2,/40100, Current Loss = 0.8748
# Epoch 2,/40200, Current Loss = 0.8462
# Epoch 2,/40300, Current Loss = 0.6315
# Epoch 2,/40400, Current Loss = 0.7724
# Epoch 2,/40500, Current Loss = 0.5967
# Epoch 2,/40600, Current Loss = 0.6558
# Epoch 2,/40700, Current Loss = 0.7471
# Epoch 2,/40800, Current Loss = 0.6675
# Epoch 2,/40900, Current Loss = 0.7255
# Epoch 2,/41000, Current Loss = 0.8488
# Epoch 2,/41100, Current Loss = 0.7790
# Epoch 2,/41200, Current Loss = 0.8408
# Epoch 2,/41300, Current Loss = 0.6708
# Epoch 2,/41400, Current Loss = 0.6583
# Epoch 2,/41500, Current Loss = 0.5692
# Epoch 2,/41600, Current Loss = 0.7673
# Epoch 2,/41700, Current Loss = 0.6158
# Epoch 2,/41800, Current Loss = 0.7099
# Epoch 2,/41900, Current Loss = 0.7740
# Epoch 2,/42000, Current Loss = 0.6281
# Epoch 2,/42100, Current Loss = 0.7973
# Epoch 2,/42200, Current Loss = 0.6551
# Epoch 2,/42300, Current Loss = 0.6103
# Epoch 2,/42400, Current Loss = 0.6790
# Epoch 2,/42500, Current Loss = 0.6421
# Epoch 2,/42600, Current Loss = 0.6293
# Epoch 2,/42700, Current Loss = 0.6723
# Epoch 2,/42800, Current Loss = 0.7511
# Epoch 2,/42900, Current Loss = 0.7175
# Epoch 2,/43000, Current Loss = 0.7709
# Epoch 2,/43100, Current Loss = 0.5814
# Epoch 2,/43200, Current Loss = 0.7943
# Epoch 2,/43300, Current Loss = 0.7800
# Epoch 2,/43400, Current Loss = 0.6896
# Epoch 2,/43500, Current Loss = 0.6475
# Epoch 2,/43600, Current Loss = 0.7277
# Epoch 2,/43700, Current Loss = 0.6859
# Epoch 2,/43800, Current Loss = 0.6876
# Epoch 2,/43900, Current Loss = 0.7460
# Epoch 2,/44000, Current Loss = 0.6819
# Epoch 2,/44100, Current Loss = 0.7666
# Epoch 2,/44200, Current Loss = 0.6948
# Epoch 2,/44300, Current Loss = 0.7595
# Epoch 2,/44400, Current Loss = 0.6744
# Epoch 2,/44500, Current Loss = 0.6365
# Epoch 2,/44600, Current Loss = 0.6647
# Epoch 2,/44700, Current Loss = 0.6072
# Epoch 2,/44800, Current Loss = 0.7334
# Epoch 2,/44900, Current Loss = 0.7397
# Epoch 2,/45000, Current Loss = 0.7831
# Epoch 2,/45100, Current Loss = 0.7716
# Epoch 2,/45200, Current Loss = 0.7217
# Epoch 2,/45300, Current Loss = 0.7682
# Epoch 2,/45400, Current Loss = 0.8747
# Epoch 2,/45500, Current Loss = 0.7028
# Epoch 2,/45600, Current Loss = 0.7059
# Epoch 2,/45700, Current Loss = 0.7654
# Epoch 2,/45800, Current Loss = 0.7206
# Epoch 2,/45900, Current Loss = 0.7755
# Epoch 2,/46000, Current Loss = 0.6357
# Epoch 2,/46100, Current Loss = 0.7627
# Epoch 2,/46200, Current Loss = 0.7562
# Epoch 2,/46300, Current Loss = 0.6997
# Epoch 2,/46400, Current Loss = 0.6020
# Epoch 2,/46500, Current Loss = 0.6890
# Epoch 2,/46600, Current Loss = 0.7024
# Epoch 2,/46700, Current Loss = 0.7559
# Epoch 2,/46800, Current Loss = 0.7801
# Epoch 2,/46900, Current Loss = 0.6917
# Epoch 2,/47000, Current Loss = 0.6396
# Epoch 2,/47100, Current Loss = 0.7743
# Epoch 2,/47200, Current Loss = 0.7496
# Epoch 2,/47300, Current Loss = 0.7159
# Epoch 2,/47400, Current Loss = 0.6616
# Epoch 2,/47500, Current Loss = 0.6705
# Epoch 2,/47600, Current Loss = 0.7628
# Epoch 2,/47700, Current Loss = 0.6678
# Epoch 2,/47800, Current Loss = 0.6923
# Epoch 2,/47900, Current Loss = 0.7042
# Epoch 2,/48000, Current Loss = 0.6447
# Epoch 2,/48100, Current Loss = 0.6913
# Epoch 2,/48200, Current Loss = 0.7923
# Epoch 2,/48300, Current Loss = 0.8132
# ...
# Epoch 4,/36000, Current Loss = 0.6552
# Epoch 4,/36100, Current Loss = 0.5390
# Epoch 4,/36200, Current Loss = 0.6328
# Epoch 4,/36300, Current Loss = 0.7031
# Epoch 4,/36400, Current Loss = 0.5848
# Epoch 4,/36500, Current Loss = 0.6368
# Epoch 4,/36600, Current Loss = 0.6575
# Epoch 4,/36700, Current Loss = 0.5609
# Epoch 4,/36800, Current Loss = 0.5625
# Epoch 4,/36900, Current Loss = 0.5850
# Epoch 4,/37000, Current Loss = 0.5777
# Epoch 4,/37100, Current Loss = 0.7886
# Epoch 4,/37200, Current Loss = 0.6659
# Epoch 4,/37300, Current Loss = 0.6126
# Epoch 4,/37400, Current Loss = 0.5089
# Epoch 4,/37500, Current Loss = 0.6281
# Epoch 4,/37600, Current Loss = 0.5822
# Epoch 4,/37700, Current Loss = 0.5535
# Epoch 4,/37800, Current Loss = 0.6664
# Epoch 4,/37900, Current Loss = 0.5018
# Epoch 4,/38000, Current Loss = 0.6635
# Epoch 4,/38100, Current Loss = 0.6204
# Epoch 4,/38200, Current Loss = 0.5323
# Epoch 4,/38300, Current Loss = 0.6200
# Epoch 4,/38400, Current Loss = 0.5371
# Epoch 4,/38500, Current Loss = 0.6968
# Epoch 4,/38600, Current Loss = 0.6507
# Epoch 4,/38700, Current Loss = 0.7163
# Epoch 4,/38800, Current Loss = 0.6171
# Epoch 4,/38900, Current Loss = 0.5586
# Epoch 4,/39000, Current Loss = 0.7126
# Epoch 4,/39100, Current Loss = 0.6062
# Epoch 4,/39200, Current Loss = 0.7315
# Epoch 4,/39300, Current Loss = 0.5560
# Epoch 4,/39400, Current Loss = 0.6545
# Epoch 4,/39500, Current Loss = 0.5314
# Epoch 4,/39600, Current Loss = 0.5179
# Epoch 4,/39700, Current Loss = 0.6381
# Epoch 4,/39800, Current Loss = 0.7228
# Epoch 4,/39900, Current Loss = 0.6814
# Epoch 4,/40000, Current Loss = 0.5685
# Epoch 4,/40100, Current Loss = 0.7868
# Epoch 4,/40200, Current Loss = 0.7522
# Epoch 4,/40300, Current Loss = 0.5469
# Epoch 4,/40400, Current Loss = 0.6887
# Epoch 4,/40500, Current Loss = 0.4886
# Epoch 4,/40600, Current Loss = 0.5966
# Epoch 4,/40700, Current Loss = 0.6826
# Epoch 4,/40800, Current Loss = 0.5905
# Epoch 4,/40900, Current Loss = 0.6602
# Epoch 4,/41000, Current Loss = 0.7747
# Epoch 4,/41100, Current Loss = 0.7196
# Epoch 4,/41200, Current Loss = 0.7500
# Epoch 4,/41300, Current Loss = 0.5839
# Epoch 4,/41400, Current Loss = 0.5930
# Epoch 4,/41500, Current Loss = 0.5001
# Epoch 4,/41600, Current Loss = 0.6898
# Epoch 4,/41700, Current Loss = 0.5195
# Epoch 4,/41800, Current Loss = 0.6169
# Epoch 4,/41900, Current Loss = 0.6706
# Epoch 4,/42000, Current Loss = 0.5457
# Epoch 4,/42100, Current Loss = 0.7326
# Epoch 4,/42200, Current Loss = 0.5955
# Epoch 4,/42300, Current Loss = 0.5309
# Epoch 4,/42400, Current Loss = 0.6092
# Epoch 4,/42500, Current Loss = 0.5807
# Epoch 4,/42600, Current Loss = 0.5601
# Epoch 4,/42700, Current Loss = 0.6073
# Epoch 4,/42800, Current Loss = 0.6728
# Epoch 4,/42900, Current Loss = 0.6371
# Epoch 4,/43000, Current Loss = 0.6804
# Epoch 4,/43100, Current Loss = 0.4987
# Epoch 4,/43200, Current Loss = 0.7247
# Epoch 4,/43300, Current Loss = 0.6704
# Epoch 4,/43400, Current Loss = 0.6118
# Epoch 4,/43500, Current Loss = 0.5324
# Epoch 4,/43600, Current Loss = 0.6050
# Epoch 4,/43700, Current Loss = 0.5978
# Epoch 4,/43800, Current Loss = 0.6415
# Epoch 4,/43900, Current Loss = 0.6554
# Epoch 4,/44000, Current Loss = 0.6325
# Epoch 4,/44100, Current Loss = 0.6907
# Epoch 4,/44200, Current Loss = 0.6309
# Epoch 4,/44300, Current Loss = 0.6982
# Epoch 4,/44400, Current Loss = 0.5728
# Epoch 4,/44500, Current Loss = 0.5711
# Epoch 4,/44600, Current Loss = 0.6059
# Epoch 4,/44700, Current Loss = 0.5335
# Epoch 4,/44800, Current Loss = 0.6538
# Epoch 4,/44900, Current Loss = 0.6813
# Epoch 4,/45000, Current Loss = 0.7078
# Epoch 4,/45100, Current Loss = 0.6694
# Epoch 4,/45200, Current Loss = 0.6529
# Epoch 4,/45300, Current Loss = 0.6530
# Epoch 4,/45400, Current Loss = 0.7847
# Epoch 4,/45500, Current Loss = 0.6233
# Epoch 4,/45600, Current Loss = 0.6473
# Epoch 4,/45700, Current Loss = 0.7048
# Epoch 4,/45800, Current Loss = 0.6588
# Epoch 4,/45900, Current Loss = 0.6960
# Epoch 4,/46000, Current Loss = 0.5697
# Epoch 4,/46100, Current Loss = 0.6741
# Epoch 4,/46200, Current Loss = 0.6576
# Epoch 4,/46300, Current Loss = 0.6242
# Epoch 4,/46400, Current Loss = 0.5113
# Epoch 4,/46500, Current Loss = 0.6064
# Epoch 4,/46600, Current Loss = 0.6116
# Epoch 4,/46700, Current Loss = 0.6697
# Epoch 4,/46800, Current Loss = 0.6788
# Epoch 4,/46900, Current Loss = 0.6429
# Epoch 4,/47000, Current Loss = 0.5447
# Epoch 4,/47100, Current Loss = 0.6921
# Epoch 4,/47200, Current Loss = 0.6674
# Epoch 4,/47300, Current Loss = 0.6177
# Epoch 4,/47400, Current Loss = 0.5881
# Epoch 4,/47500, Current Loss = 0.6064
# Epoch 4,/47600, Current Loss = 0.6796
# Epoch 4,/47700, Current Loss = 0.6063
# Epoch 4,/47800, Current Loss = 0.6488
# Epoch 4,/47900, Current Loss = 0.6492
# Epoch 4,/48000, Current Loss = 0.5968
# Epoch 4,/48100, Current Loss = 0.6241
# Epoch 4,/48200, Current Loss = 0.7053
# Epoch 4,/48300, Current Loss = 0.7305
# Epoch 4,/48400, Current Loss = 0.5829
# Epoch 4,/48500, Current Loss = 0.5641
# Epoch 4,/48600, Current Loss = 0.5941
# Epoch 4,/48700, Current Loss = 0.5474
# Epoch 4,/48800, Current Loss = 0.6184
# Epoch 4,/48900, Current Loss = 0.5150
# Epoch 4,/49000, Current Loss = 0.5283
# Epoch 4,/49100, Current Loss = 0.6753
# Epoch 4,/49200, Current Loss = 0.6575
# Epoch 4,/49300, Current Loss = 0.6171
# Epoch 4,/49400, Current Loss = 0.6474
# Epoch 4,/49500, Current Loss = 0.6089
# Epoch 4,/49600, Current Loss = 0.6722
# Epoch 4,/49700, Current Loss = 0.7190
# Epoch 4,/49800, Current Loss = 0.5954
# Epoch 4,/49900, Current Loss = 0.5489
# Epoch 4,/50000, Current Loss = 0.6108
# Epoch 4,/50100, Current Loss = 0.7436
# Epoch 4,/50200, Current Loss = 0.6433
# Epoch 4,/50300, Current Loss = 0.6023
# Epoch 4,/50400, Current Loss = 0.6620
# Epoch 4,/50500, Current Loss = 0.6144
# Epoch 4,/50600, Current Loss = 0.7990
# Epoch 4,/50700, Current Loss = 0.5288
# Epoch 4,/50800, Current Loss = 0.6766
# Epoch 4,/50900, Current Loss = 0.6156
# Epoch 4,/51000, Current Loss = 0.7047
# Epoch 4,/51100, Current Loss = 0.6391
# Epoch 4,/51200, Current Loss = 0.6265
# Epoch 4,/51300, Current Loss = 0.6601
# Epoch 4,/51400, Current Loss = 0.5694
# Epoch 4,/51500, Current Loss = 0.7574
# Epoch 4,/51600, Current Loss = 0.6960
# Epoch 4,/51700, Current Loss = 0.6998
# Epoch 4,/51800, Current Loss = 0.6450
# Epoch 4,/51900, Current Loss = 0.6310
# Epoch 4,/52000, Current Loss = 0.5365
# Epoch 4,/52100, Current Loss = 0.5839
# Epoch 4,/52200, Current Loss = 0.5991
# Epoch 4,/52300, Current Loss = 0.6190
# Epoch 4,/52400, Current Loss = 0.5884
# Epoch 4,/52500, Current Loss = 0.6974
# Epoch 4,/52600, Current Loss = 0.4898
# Epoch 4,/52700, Current Loss = 0.5012
# Epoch 4,/52800, Current Loss = 0.5854
# Epoch 4,/52900, Current Loss = 0.6511
# Epoch 4,/53000, Current Loss = 0.6847
# Epoch 4,/53100, Current Loss = 0.7187
# Epoch 4,/53200, Current Loss = 0.6248
# Epoch 4,/53300, Current Loss = 0.6156
# Epoch 4,/53400, Current Loss = 0.5844
# Epoch 4,/53500, Current Loss = 0.6378
# Epoch 4,/53600, Current Loss = 0.5812
# Epoch 4,/53700, Current Loss = 0.6745
# Epoch 4,/53800, Current Loss = 0.7841
# Epoch 4,/53900, Current Loss = 0.5500
# Epoch 4,/54000, Current Loss = 0.5961
# Epoch 4,/54100, Current Loss = 0.6552
# Epoch 4,/54200, Current Loss = 0.5760
# Epoch 4,/54300, Current Loss = 0.5915
# Epoch 4,/54400, Current Loss = 0.5528
# Epoch 4,/54500, Current Loss = 0.6448
# Epoch 4,/54600, Current Loss = 0.6546
# Epoch 4,/54700, Current Loss = 0.5113
# Epoch 4,/54800, Current Loss = 0.8084
# Epoch 4,/54900, Current Loss = 0.6567
# Epoch 4,/55000, Current Loss = 0.5487
# Epoch 4,/55100, Current Loss = 0.6537
# Epoch 4,/55200, Current Loss = 0.5707
# Epoch 4,/55300, Current Loss = 0.5670
# Epoch 4,/55400, Current Loss = 0.5510
# Epoch 4,/55500, Current Loss = 0.6132
# Epoch 4,/55600, Current Loss = 0.5962
# Epoch 4,/55700, Current Loss = 0.6164
# Epoch 4,/55800, Current Loss = 0.7147
# Epoch 4,/55900, Current Loss = 0.5988
# Epoch 4,/56000, Current Loss = 0.5951
# Epoch 4,/56100, Current Loss = 0.6759
# Epoch 4,/56200, Current Loss = 0.5403
# Epoch 4,/56300, Current Loss = 0.6377
# Epoch 4,/56400, Current Loss = 0.6951
# Epoch 4,/56500, Current Loss = 0.5055
# Epoch 4,/56600, Current Loss = 0.6058
# Epoch 4,/56700, Current Loss = 0.6766
# Epoch 4,/56800, Current Loss = 0.5686
# Epoch 4,/56900, Current Loss = 0.6716
# Epoch 4,/57000, Current Loss = 0.6249
# Epoch 4,/57100, Current Loss = 0.6472
# Epoch 4,/57200, Current Loss = 0.6587
# Epoch 4,/57300, Current Loss = 0.5701
# Epoch 4,/57400, Current Loss = 0.5808
# Epoch 4,/57500, Current Loss = 0.5590
# Epoch 4,/57600, Current Loss = 0.7937
# Epoch 4,/57700, Current Loss = 0.6365
# Epoch 4,/57800, Current Loss = 0.4469
# Epoch 4,/57900, Current Loss = 0.6060
# Epoch 4,/58000, Current Loss = 0.5802
# Epoch 4,/58100, Current Loss = 0.5478
# Epoch 4,/58200, Current Loss = 0.6050
# Epoch 4,/58300, Current Loss = 0.7004
# Epoch 4,/58400, Current Loss = 0.4796
# Epoch 4,/58500, Current Loss = 0.4949
# Epoch 4,/58600, Current Loss = 0.5983
# Epoch 4,/58700, Current Loss = 0.6515
# Epoch 4,/58800, Current Loss = 0.6227
# Epoch 4,/58900, Current Loss = 0.5865
# Epoch 4,/59000, Current Loss = 0.6628
# Epoch 4,/59100, Current Loss = 0.7823
# Epoch 4,/59200, Current Loss = 0.6581
# Epoch 4,/59300, Current Loss = 0.5751
# Epoch 4,/59400, Current Loss = 0.5472
# Epoch 4,/59500, Current Loss = 0.5734
# Epoch 4,/59600, Current Loss = 0.6438
# Epoch 4,/59700, Current Loss = 0.5805
# Epoch 4,/59800, Current Loss = 0.6500
# Epoch 4,/59900, Current Loss = 0.6539
# Epoch 4,/60000, Current Loss = 0.7920
# Epoch 4,/60100, Current Loss = 0.6950
# Epoch 4,/60200, Current Loss = 0.5040
# Epoch 4,/60300, Current Loss = 0.6349
# Epoch 4,/60400, Current Loss = 0.5627
# Epoch 4,/60500, Current Loss = 0.5699
# Epoch 4,/60600, Current Loss = 0.5961
# Epoch 4,/60700, Current Loss = 0.4885
# Epoch 4,/60800, Current Loss = 0.6259
# Epoch 4,/60900, Current Loss = 0.5754
# Epoch 4,/61000, Current Loss = 0.4657
# Epoch 4,/61100, Current Loss = 0.7867
# Epoch 4,/61200, Current Loss = 0.5970
# Epoch 4,/61300, Current Loss = 0.6043
# Epoch 4,/61400, Current Loss = 0.6972
# Epoch 4,/61500, Current Loss = 0.6013
# Epoch 4,/61600, Current Loss = 0.6148
# Epoch 4,/61700, Current Loss = 0.5537
# Epoch 4,/61800, Current Loss = 0.5650
# Epoch 4,/61900, Current Loss = 0.7862
# Epoch 4,/62000, Current Loss = 0.6597
# Epoch 4,/62100, Current Loss = 0.5655
# Epoch 4,/62200, Current Loss = 0.5948
# Epoch 4,/62300, Current Loss = 0.7315
# Epoch 4,/62400, Current Loss = 0.5773
# Epoch 4,/62500, Current Loss = 0.5719
# Epoch 4,/62600, Current Loss = 0.5873
# Epoch 4,/62700, Current Loss = 0.6516
# Epoch 4,/62800, Current Loss = 0.5734
# Epoch 4,/62900, Current Loss = 0.5852
# Epoch 4,/63000, Current Loss = 0.5219
# Epoch 4,/63100, Current Loss = 0.6680
# Epoch 4,/63200, Current Loss = 0.5841
# Epoch 4,/63300, Current Loss = 0.5635
# Epoch 4,/63400, Current Loss = 0.5802
# Epoch 4,/63500, Current Loss = 0.7747
# Epoch 4,/63600, Current Loss = 0.5997
# Epoch 4,/63700, Current Loss = 0.6198
# Epoch 4,/63800, Current Loss = 0.5445
# Epoch 4,/63900, Current Loss = 0.7018
# Epoch 4,/64000, Current Loss = 0.6118
# Epoch 4,/64100, Current Loss = 0.6282
# Epoch 4,/64200, Current Loss = 0.4621
# Epoch 4,/64300, Current Loss = 0.4794
# Epoch 4,/64400, Current Loss = 0.7266
# Epoch 4,/64500, Current Loss = 0.5657
# Epoch 4,/64600, Current Loss = 0.5776
# Epoch 4,/64700, Current Loss = 0.4994
# Epoch 4,/64800, Current Loss = 0.6240
# Epoch 4,/64900, Current Loss = 0.5955
# Epoch 4,/65000, Current Loss = 0.6200
# Epoch 4,/65100, Current Loss = 0.7698
# Epoch 4,/65200, Current Loss = 0.5708
# Epoch 4,/65300, Current Loss = 0.5747
# Epoch 4,/65400, Current Loss = 0.6428
# Epoch 4,/65500, Current Loss = 0.7118
# Epoch 4,/65600, Current Loss = 0.5442
# Epoch 4,/65700, Current Loss = 0.5366
# Epoch 4,/65800, Current Loss = 0.4655
# Epoch 4,/65900, Current Loss = 0.7155
# Epoch 4,/66000, Current Loss = 0.5820
# Epoch 4,/66100, Current Loss = 0.5642
# Epoch 4,/66200, Current Loss = 0.5574
# Epoch 4,/66300, Current Loss = 0.6325
# Epoch 4,/66400, Current Loss = 0.6361
# Epoch 4,/66500, Current Loss = 0.6517
# Epoch 4,/66600, Current Loss = 0.6655
# Epoch 4,/66700, Current Loss = 0.6708
# Epoch 4,/66800, Current Loss = 0.7094
# Epoch 4,/66900, Current Loss = 0.6836
# Epoch 4,/67000, Current Loss = 0.6659
# Epoch 4,/67100, Current Loss = 0.5878
# Epoch 4,/67200, Current Loss = 0.5779
# Epoch 4,/67300, Current Loss = 0.6527
# Epoch 4,/67400, Current Loss = 0.6015
# Epoch 4,/67500, Current Loss = 0.5835
# Epoch 4,/67600, Current Loss = 0.5938
# Epoch 4,/67700, Current Loss = 0.4918
# Epoch 4,/67800, Current Loss = 0.6072
# Epoch 4,/67900, Current Loss = 0.6002
# Epoch 4,/68000, Current Loss = 0.5756
# Epoch 4,/68100, Current Loss = 0.5977
# Epoch 4,/68200, Current Loss = 0.7008
# Epoch 4,/68300, Current Loss = 0.6472
# Epoch 4,/68400, Current Loss = 0.6410
# Epoch 4,/68500, Current Loss = 0.5298
# Epoch 4,/68600, Current Loss = 0.5467
# Epoch 4,/68700, Current Loss = 0.5583
# Epoch 4,/68800, Current Loss = 0.6425
# Epoch 4,/68900, Current Loss = 0.6020
# Epoch 4,/69000, Current Loss = 0.4809
# Epoch 4,/69100, Current Loss = 0.5608
# Epoch 4,/69200, Current Loss = 0.5795
# Epoch 4,/69300, Current Loss = 0.6234
# Epoch 4,/69400, Current Loss = 0.5542
# Epoch 4,/69500, Current Loss = 0.6216
# Epoch 4,/69600, Current Loss = 0.7138
# Epoch 4,/69700, Current Loss = 0.7514
# Epoch 4,/69800, Current Loss = 0.6545
# Epoch 4,/69900, Current Loss = 0.6034
# Epoch 4,/70000, Current Loss = 0.5683
# Epoch 4,/70100, Current Loss = 0.5013
# Epoch 4,/70200, Current Loss = 0.5759
# Epoch 4,/70300, Current Loss = 0.5495
# Epoch 4,/70400, Current Loss = 0.7330
# Epoch 4,/70500, Current Loss = 0.5939
# Epoch 4,/70600, Current Loss = 0.6234
# Epoch 4,/70700, Current Loss = 0.5277
# Epoch 4,/70800, Current Loss = 0.5727
# Epoch 4,/70900, Current Loss = 0.5944
# Epoch 4,/71000, Current Loss = 0.6271
# Epoch 4,/71100, Current Loss = 0.7106
# Epoch 4,/71200, Current Loss = 0.5966
# Epoch 4,/71300, Current Loss = 0.5977
# Epoch 4,/71400, Current Loss = 0.5815
# Epoch 4,/71500, Current Loss = 0.6279
# Epoch 4,/71600, Current Loss = 0.5974
# Epoch 4,/71700, Current Loss = 0.6139
# Epoch 4,/71800, Current Loss = 0.6113
# Epoch 4,/71900, Current Loss = 0.5467
# Epoch 4,/72000, Current Loss = 0.5877
# Epoch 4,/72100, Current Loss = 0.6292
# Epoch 4,/72200, Current Loss = 0.6584
# Epoch 4,/72300, Current Loss = 0.6603
# Epoch 4,/72400, Current Loss = 0.5267
# Epoch 4,/72500, Current Loss = 0.6412
# Epoch 4,/72600, Current Loss = 0.5760
# Epoch 4,/72700, Current Loss = 0.6347
# Epoch 4,/72800, Current Loss = 0.6286
# Epoch 4,/72900, Current Loss = 0.5817
# Epoch 4,/73000, Current Loss = 0.6737
# Epoch 4,/73100, Current Loss = 0.5136
# Epoch 4,/73200, Current Loss = 0.5375
# Epoch 4,/73300, Current Loss = 0.6718
# Epoch 4,/73400, Current Loss = 0.6037
# Epoch 4,/73500, Current Loss = 0.5378
# Epoch 4,/73600, Current Loss = 0.5989
# Epoch 4,/73700, Current Loss = 0.5899
# Epoch 4,/73800, Current Loss = 0.4810
# Epoch 4,/73900, Current Loss = 0.6429
# Epoch 4,/74000, Current Loss = 0.6168
# Epoch 4,/74100, Current Loss = 0.6094
# Epoch 4,/74200, Current Loss = 0.5440
# Epoch 4,/74300, Current Loss = 0.5222
# Epoch 4,/74400, Current Loss = 0.6686
# Epoch 4,/74500, Current Loss = 0.5842
# Epoch 4,/74600, Current Loss = 0.4701
# Epoch 4,/74700, Current Loss = 0.4977
# Epoch 4,/74800, Current Loss = 0.5137
# Epoch 4,/74900, Current Loss = 0.5344
# Epoch 4,/75000, Current Loss = 0.6031
# Epoch 4,/75100, Current Loss = 0.5923
# Epoch 4,/75200, Current Loss = 0.5846
# Epoch 4,/75300, Current Loss = 0.5979
# Epoch 4,/75400, Current Loss = 0.6424
# Epoch 4,/75500, Current Loss = 0.6046
# Epoch 4,/75600, Current Loss = 0.4932
# Epoch 4,/75700, Current Loss = 0.6599
# Epoch 4,/75800, Current Loss = 0.6014
# Epoch 4,/75900, Current Loss = 0.6293
# Epoch 4,/76000, Current Loss = 0.4978
# Epoch 4,/76100, Current Loss = 0.6295
# Epoch 4,/76200, Current Loss = 0.6001
# Epoch 4,/76300, Current Loss = 0.6391
# Epoch 4,/76400, Current Loss = 0.6196
# Epoch 4,/76500, Current Loss = 0.5217
# Epoch 4,/76600, Current Loss = 0.6100
# Epoch 4,/76700, Current Loss = 0.4735
# Epoch 4,/76800, Current Loss = 0.5751
# Epoch 4,/76900, Current Loss = 0.5734
# Epoch 4,/77000, Current Loss = 0.6134
# Epoch 4,/77100, Current Loss = 0.7084
# Epoch 4,/77200, Current Loss = 0.6597
# Epoch 4,/77300, Current Loss = 0.4967
# Epoch 4,/77400, Current Loss = 0.6276
# Epoch 4,/77500, Current Loss = 0.6187
# Epoch 4,/77600, Current Loss = 0.6754
# Epoch 4,/77700, Current Loss = 0.5905
# Epoch 4,/77800, Current Loss = 0.6101
# Epoch 4,/77900, Current Loss = 0.5636
# Epoch 4,/78000, Current Loss = 0.5570

# %%
# train(print_every=500)

# %%
def test_3(print_every=5000):
    accuracy = 0
    num_of_letters = 0
    with torch.no_grad():

        for counter, (english_name, hebrew_name) in enumerate(test_data):
            encoder_hidden = encoder_model_3.initHidden()

           

            encoder_outputs = torch.zeros(len(english_name), 1, encoder_model_3.hidden_size).cuda()
    
            for i, letter in enumerate(english_name):
                letter_tensor = torch.tensor([[letter]]).cuda()
                encoder_output, encoder_hidden = encoder_model_3(letter_tensor, encoder_hidden)
#                 print()
                encoder_outputs[i] = encoder_output
            
            decoder_input = torch.tensor([[0]]).cuda()
            decoder_hidden = encoder_hidden
            
            guessed_word = []
            
            for i in range(MAX_LABEL_LENGTH):
                decoder_output, decoder_hidden = decoder_model_3(decoder_input, decoder_hidden,encoder_outputs)
                
                
                _, top_indexes = decoder_output.topk(1)
#                 print(decoder_output.size())
                decoder_input = top_indexes.squeeze(0).detach()
#                 print(torch.max(decoder_output,dim=2).indices.size())
                guessed_word.append(torch.max(decoder_output,dim=2).indices[0])
                
#                 print(decoder_output.size())
                
            
            for i in range(MAX_LABEL_LENGTH):
                if guessed_word[i] == hebrew_name[i] and guessed_word[i] == 1:
                    break
                    
                num_of_letters += 1
                if guessed_word[i] == hebrew_name[i]:
                    accuracy += 1

        
            if counter % print_every == 0 and counter != 0:
                print(counter)
    print(accuracy / num_of_letters)

# %%
test_3(print_every=500)
# Out:
# <ipython-input-9-71cb0f34e1fa>:54: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   weights = F.softmax(weights)
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 0.6129360884190294

# %%
print(datetime.datetime.now())
