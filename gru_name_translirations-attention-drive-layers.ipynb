# %%
# %autosave 60
import random
# Out:
# Autosaving every 60 seconds

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-


import pandas as pd
with open('data/names.csv', 'r',  encoding="utf-8")as f:
    string = ""

    
    line = f.readline()

    
    
    while line:
        
        if len(line) > 2 and line[-2] == ',':
            line = line[:-2] + '\n'
        if len(line) > 2 and line[-2] == '.':
            line = line[:-2] + '\n'
        if '’' in line:
            line = line.replace("’", "\'")
        if '׳' in line:
            line = line.replace("׳", "\'")
        if 'ʼ' in line:
            line = line.replace('ʼ', "")
        if 'ʾ' in line:
            line = line.replace('ʾ', "")
        if 'ʹ' in line:
            line = line.replace('ʹ', "")
        if 'ʿ' in line:
            line = line.replace('ʿ', "")
        if 'ӏ' in line:
            line = line.replace('ӏ', "l")
        if '–' in line:
            line = line.replace('–', "-")
        
        
        
        if ",," in line:
            # print(line)
            
            line = line.replace(",,", ",")
        if '\'' in line:
            line = line.replace('\'', '\\\'')
        if '\"' in line:
            line = line.replace('\"', '\\\"')
        if '(' in line or ')' in line:
            line = ""
        if line == 'hebrew,english\n':
            # print(index)
            line= ""
        string += line
        line = f.readline()


with open('data/names_after_processing.csv', 'w',  encoding="utf-8") as fi:
    fi.write(string)

df = pd.read_csv("data/names_after_processing.csv", names=['hebrew', 'english'],header=None)
# print(len(df))
wierd_charachters =  ['װ','í', 'á', 'ó', 'č',  'š', 'ş',  'ł',  'ø', 'é', 'ő', 'î', 'è', 'ć', 'ž', 'ö', 'ň', 'ẓ', 'ü', 'ť', 'ý', 'ã', 'ë', 'ī', 'ḥ', 'ă', 'ñ', 'ä', '־', 'ʻ', 'ğ', 'ï', 'ģ', 'ń', 'ç', 'ū', 'ú', 'ļ', 'ṭ', 'å', 'ḳ', '̈', '1', 'ĥ', 'ð', 'ě', 'ō', 'ô', 'ė', 'ò', 'ř', 'ț',  'ą', 'ß', 'đ', '\xa0', ':', 'æ', 'ê', 'â', 'ı', 'ù', 'à', 'ś', '︠', '︡',  'ż',  'ţ', 'þ', 'ľ',  'ā', '0', 'ų', 'ĭ', '8', 'ē', 'ņ', 'ÿ', 'ַ', 'θ', 'ε', 'δ', 'ω', 'ρ', 'α', 'ό', 'π', 'υ', 'λ', 'ς', '3', 'õ', 'م', 'ا', 'ل', 'ي', 'ن', '،', 'ׂ', '$', '5', '2', '室', '田', '一', '雄', '′', 'س', 'ف', 'ầ', 'ů', '͡', 'ŏ', 'ả', 'ź', 'ì', '̣', 'ب', 'ر', 'و', 'ױ', '_', 'ə', 'û', 'ŭ', 'د', '9', 'ṣ', 'ḵ', '6', 'أ', 'ك', 'گ', 'ی', '!', 'ت',  'ď', '4', 'ŵ', 'ķ', 'ش', 'ứ', '7', 'œ', 'ũ', 'ű', 'ụ', 'ه', 'ạ', 'ح', 'ذ', 'τ', 'ά', 'ι', 'ṇ','ę', '׳', 'ׂ', '̇', '’', '.', '־', '/', 'ִ', 'ְ', 'ּ', 'ș', 'ʼ', 'ֶ', 'ַ', 'ʾ', '室', '田', '一', '雄', 'ײ', '‘', 'ʹ', 'ׁ', ':', '[', 'س', 'ي', 'ف', 'ر', 'ت', 'ֹ', 'ا', 'ن', 'ṿ', 'ָ', 'ֵ', '!', 'ʿ', '_', 'أ', 'ب', 'و', '`', '1', '0', '8', 'ش', 'ل', 'κ', 'ӏ', 'ׄ', 'م', 'د', '2', 'τ', 'ά', 'ι', 'θ', 'ε', 'ο', 'δ', 'ω', 'ρ', 'α', 'ό', 'π', 'υ', 'λ', 'ς', '\xa0', '،', '״', 'ױ', '5', 'ك']

df.drop(df[(df['english'] == 'i')|
(df['english'] == 'ii')|(df['english'] == 'iii')
|(df['english'] == 'iv')|(df['english'] == 'v')
|(df['english'] == 'vi')|(df['english'] == 'vii')
|(df['english'] == 'viii')|(df['english'] == 'ix')
|(df['english'] == 'x')|(df['english'] == 'xi')
|(df['english'] == 'xii')|(df['english'] == 'xiii')
|(df['english'] == 'prince')|(df['english'] == 'princess')
|(df['english'] == 'dutchess')|(df['english'] == 'duke')
|(df['english'] == 'mr')|(df['english'] == 'ms')|(df['english'] == 'mrs')
|(df['english'] == 'the')|(df['english'] == 'for')|(df['english'] == 'of')
|(df['english'] == 'king')|(df['english'] == 'queen')|(df['english'] == 'is')
|(df['english'].str.contains('^[a-z][.]', regex =True))|(df['english'].str.contains('^[א-ת][.]', regex =True))
|(df['english'].str.contains('^[a-z]$', regex =True))|(df['english'].str.contains('^[א-ת]$', regex =True))
].index, inplace=True)

df.dropna(axis=0, how='any',  inplace=True)

for char in wierd_charachters:
    df.drop(df[(df['english'].str.contains(char, regex=False))|(df['hebrew'].str.contains(char, regex=False)) ].index, inplace=True)
    
df.dropna(axis=0, how='any',  inplace=True)

df.drop(df.loc[df['english'].str.contains('[א-ת]', regex=True)].index, inplace=True)

df.dropna(axis=0, how='any',  inplace=True)


df.reset_index(drop=True, inplace=True)

df.to_csv('names_final.csv', index = False)
print(len(df))
df.drop_duplicates(inplace=True, ignore_index=True)
print(len(df))
# Out:
# 254928
# 87564

# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torch
import torch.nn.functional as F

def train_validate_test_split(dataframe, train_percent=.8, validate_percent=.1, seed=42):
    np.random.seed(seed)
    perm = np.random.permutation(dataframe.index)
   
    m = len(dataframe.index)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    print(max(perm))
    
    train = dataframe.iloc[perm[:train_end]]
    validate = dataframe.iloc[perm[train_end:validate_end]]
    test = dataframe.iloc[perm[validate_end:]]
    
    return train, validate, test

# %%
MAX_LABEL_LENGTH = 12
class Vocab:
    def __init__(self, is_hebrew):
        self.char2id = {}
        self.id2char = {}
        if is_hebrew:
            self.n_chars = 2        
            self.char2id['^'] = 0
            self.char2id['$'] = 1
            self.id2char[0] = '^'
            self.id2char[1] = '$'
        else:
            self.n_chars = 0
            
        
        
        
        
    def index_text(self, text):
        indexes = [self.index_char(c) for c in text]
        return indexes
    
    def index_char(self, c):
        if c not in self.char2id:
            self.char2id[c] = self.n_chars
            self.id2char[self.n_chars] = c
            self.n_chars += 1
        return self.char2id[c]
            
            
def load_data(data, vocab_english, vocab_hebrew):
    data_sequences = []
    max_word = 0
    num_more_than_20 = 0 
    max_word_value = None
    for text in data.itertuples():
        indexes_english = vocab_english.index_text(text.english)
        indexes_hebrew = vocab_hebrew.index_text(text.hebrew)
        if len(indexes_hebrew) > max_word:
            max_word = len(indexes_hebrew)
            max_word_value = indexes_hebrew
        if len(indexes_hebrew) <= MAX_LABEL_LENGTH:
            for i in range(len(indexes_hebrew),MAX_LABEL_LENGTH, 1):
                indexes_hebrew.append(1)
            data_sequences.append((indexes_english, indexes_hebrew))

    return data_sequences

vocab_english = Vocab(False)
vocab_hebrew = Vocab(True)
train_set, validation_set, test_set = train_validate_test_split(dataframe=df)

train_data = load_data(train_set,vocab_english, vocab_hebrew)

dev_data = load_data(validation_set,vocab_english, vocab_hebrew)

test_data = load_data(test_set,vocab_english, vocab_hebrew)



print(f'Train size {len(train_data)}, Dev size {len(dev_data)}, Test size {len(test_data)} vocab english size {vocab_english.n_chars} vocab hebrew size {vocab_hebrew.n_chars}')
# Out:
# 87563
# Train size 69562, Dev size 8700, Test size 8710 vocab english size 30 vocab hebrew size 34

# %%
small_train_data = train_data[:8000]
len(small_train_data)
# Out:
# 8000

# %%
class GRU_encoder(nn.Module):
    def __init__(self, input_size, hidden_size, embedding_size, num_of_layers):
        super(GRU_encoder, self).__init__()
        
        self.hidden_size = hidden_size
        self.input_size = input_size
        self.num_of_layers = num_of_layers
        
        self.embedding = nn.Embedding(input_size, embedding_size).cuda()
        
        self.rnn = nn.GRU(embedding_size, hidden_size, num_layers=num_of_layers).cuda()
        
    def forward(self, input_letter, hidden):
        output = self.embedding(input_letter)
        
        
        
        output, hidden = self.rnn(output, hidden)
        
        return output, hidden
        
    def initHidden(self):
        return torch.zeros(self.num_of_layers, 1, self.hidden_size).cuda()

# %%
import numpy as np
class GRU_decoder(nn.Module):
    def __init__(self, ouput_size, hidden_size, embedding_size, num_of_layers):
        super(GRU_decoder, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_of_layers = num_of_layers
        
        self.embedding = nn.Embedding(ouput_size, embedding_size).cuda()
        
        self.rnn = nn.GRU(embedding_size, hidden_size, num_layers=num_of_layers).cuda()
        
        self.linear_attention = nn.Linear(2 * hidden_size, hidden_size).cuda()
        
        self.linear_context = nn.Linear(2 * hidden_size, hidden_size).cuda()
        
        self.v = nn.Parameter(torch.FloatTensor(hidden_size, 1)).cuda()
        
        self.v = nn.init.xavier_normal_(self.v)
        
        self.linear = nn.Linear(hidden_size, ouput_size).cuda()
        
        
        
    def forward(self, output_letter, hidden, encoder_outputs):
        output = self.embedding(output_letter)
        
#         print("hidden" + str(hidden.size()))
#         print(encoder_outputs.size())
    
        weighted_encoder_outputs = torch.clone(encoder_outputs)
        alphas = torch.zeros(len(encoder_outputs), self.num_of_layers).cuda()
#         print(hidden)
#         print(encoder_outputs)
        
        for i, encoder_output in enumerate(encoder_outputs):
            encoder_output = encoder_output.reshape(1,1,-1)
#             print("encoder_outputs" + str(encoder_output.size()))
#             print().size())
#             print(hidden[0][0].size())
#             print(encoder_output[0][0].size())
#             print((torch.cat((hidden[0][0], encoder_output[0][0]))))
            alphas_layers = torch.zeros(self.num_of_layers).cuda()
            
            for j in range(self.num_of_layers):
#                 print(torch.cat((hidden[j][0], encoder_output[0][0])))
                w = torch.tanh(self.linear_attention(torch.cat((hidden[j][0], encoder_output[0][0]))))
#                 print(w)
                w = w.reshape(self.hidden_size, 1)
            
            
#                 print(self.v)
#                 print(w)
                score = torch.mm(self.v.T, w)
#                 print(score)
                
                alphas_layers[j] = score
                
#             alphas.append
            alphas[i] = alphas_layers
#         print(alphas)
        
#             alphas = 1              
#             weighted_encoder_outputs.append(encoder_output)
#         print(alphas.size())
#         print(encoder_outputs[0][0][0])
#         print(alphas)
        alphas = F.softmax(alphas, dim=0)
#         print(alphas)
        alphas = alphas.reshape(len(alphas), self.num_of_layers, 1)
        
#         print(alphas)
#         print(encoder_outputs.size())
#         print(encoder_outputs)
        weighted_encoder_outputs =  torch.mul(encoder_outputs, alphas)
#         print(weighted_encoder_outputs)
#         print(weighted_encoder_outputs[0][0][0])
#         print(alphas[0])
#         print(context)
#         print(weighted_encoder_outputs.size())
#         print(weighted_encoder_outputs[0].size())
#         print(alphas)
        context = torch.sum(weighted_encoder_outputs, dim=0, keepdim=True)
#         print(weighted_encoder_outputs[0].size())
#         print(context)
        
        
#         weights_i = F.softmax(score(hidden, encoder_outputs[i]))
        
#         score(hidden, outputs[i]) = v.T* F.tanh(self.linear_attention(hidden+outputs[i]))
        
#         context = sum(weights*outputs)
        context = context.reshape(self.num_of_layers, 1, self.hidden_size)
#         print(context.size())
#         print(hidden.size())
#         print(hidden[1][0])
        hidden_concatenated = torch.zeros(self.num_of_layers, 1, self.hidden_size*2).cuda()
        for k in range(self.num_of_layers):
#             print(hidden[k][0])
#             print(context[k][0])
#             print(torch.cat((hidden[k][0], context[k][0])))
            hidden_concatenated[k][0] = torch.cat((hidden[k][0], context[k][0]))
#         print(hidden_concatenated.size())
#         hidden = hidden.reshape(self.num_of_layers,1,2*self.hidden_size)
        
        hidden = self.linear_context(hidden_concatenated)
#         print(hidden.size())
        output = F.relu(hidden)
    
        output, hidden = self.rnn(output, hidden)
        
#         print(output.size())
#         print(hidden.size())
        
        output = self.linear(output)
        
#         output = F.softmax(output)
        
        return output, hidden

# %%
# class seq2seq_GRU(nn.Module):
    
#     def __init__(self, input_size, output_size, hidden_size, embedding_size):
#         super(seq2seq_GRU, self).__init__()
        
#         self.encoder = GRU_encoder(input_size=input_size, hidden_size=hidden_size, embedding_size=embedding_size)
                
#         self.decoder = GRU_decoder(output_size=output_size, hidden_size=hidden_size, embedding_size=embedding_size)
        
        
#     def forward(self, input_word):
#         output, hidden = self.encoder(input_word)
        
#         output = self.decoder(, hidden)

# %%
encoder_model = GRU_encoder(vocab_english.n_chars, 300, 64, 2)
decoder_model = GRU_decoder(vocab_hebrew.n_chars, 300, 64, 2)

encoder_optimizer = optim.Adam(params=encoder_model.parameters(), lr=0.0001)
decoder_optimizer = optim.Adam(params=decoder_model.parameters(), lr=0.0001)

critertion = nn.CrossEntropyLoss()

# %%
def train(n_epochs=4, print_every=5000):
    loss = 0

    for e in range(1, n_epochs + 1):

        for counter, (english_name, hebrew_name) in enumerate(small_train_data):
            encoder_hidden = encoder_model.initHidden()

            encoder_optimizer.zero_grad()
            decoder_optimizer.zero_grad()

    #         english_name_tensor = torch.LongTensor(english_name).cuda()
            encoder_outputs = torch.zeros(len(english_name), 1, encoder_model.hidden_size).cuda()
    #         hebrew_name_tensor = torch.LongTensor(hebrew_name).cuda()
    
            for i, letter in enumerate(english_name):
                letter_tensor = torch.tensor([[letter]]).cuda()
                encoder_output, encoder_hidden = encoder_model(letter_tensor, encoder_hidden)
                
                encoder_outputs[i] = encoder_output
            
            decoder_input = torch.tensor([[0]]).cuda()
            decoder_hidden = encoder_hidden
            
            transliration_loss = 0 
            
            
            for i in range(len(hebrew_name)):
#                 print(i)
                decoder_output, decoder_hidden = decoder_model(decoder_input, decoder_hidden, encoder_outputs)
#                 print(i)
                
                
                _, top_indexes = decoder_output.topk(1)

                decoder_input = top_indexes.squeeze(0).detach()
#                 return
                
#                 print(decoder_hidden.size())
                transliration_loss += critertion(decoder_output.reshape(decoder_output.shape[1], decoder_output.shape[2]), torch.tensor([hebrew_name[i]]).cuda())
                if decoder_input.item() == [1]:
                    break
#             return 
            transliration_loss.backward()

            encoder_optimizer.step()
            decoder_optimizer.step()

            loss += transliration_loss.item() / len(hebrew_name)


            if counter % print_every == 0 and counter != 0:
                loss = loss / print_every
                print('Epoch %d,/%d, Current Loss = %.4f' % (e, counter,loss))
                loss = 0

# %%
train(print_every=100)
# Out:
# Epoch 1,/100, Current Loss = 2.4681
# Epoch 1,/200, Current Loss = 1.9174
# Epoch 1,/300, Current Loss = 1.7022
# Epoch 1,/400, Current Loss = 1.6178
# Epoch 1,/500, Current Loss = 1.6239
# Epoch 1,/600, Current Loss = 1.6092
# Epoch 1,/700, Current Loss = 1.5421
# Epoch 1,/800, Current Loss = 1.5439
# Epoch 1,/900, Current Loss = 1.5848
# Epoch 1,/1000, Current Loss = 1.5446
# Epoch 1,/1100, Current Loss = 1.4686
# Epoch 1,/1200, Current Loss = 1.4581
# Epoch 1,/1300, Current Loss = 1.4670
# Epoch 1,/1400, Current Loss = 1.4765
# Epoch 1,/1500, Current Loss = 1.5580
# Epoch 1,/1600, Current Loss = 1.4941
# Epoch 1,/1700, Current Loss = 1.5672
# Epoch 1,/1800, Current Loss = 1.4518
# Epoch 1,/1900, Current Loss = 1.5300
# Epoch 1,/2000, Current Loss = 1.4841
# Epoch 1,/2100, Current Loss = 1.4921
# Epoch 1,/2200, Current Loss = 1.4567
# Epoch 1,/2300, Current Loss = 1.4639
# Epoch 1,/2400, Current Loss = 1.3852
# Epoch 1,/2500, Current Loss = 1.3449
# Epoch 1,/2600, Current Loss = 1.4227
# Epoch 1,/2700, Current Loss = 1.3673
# Epoch 1,/2800, Current Loss = 1.2852
# Epoch 1,/2900, Current Loss = 1.4315
# Epoch 1,/3000, Current Loss = 1.3216
# Epoch 1,/3100, Current Loss = 1.2846
# Epoch 1,/3200, Current Loss = 1.3539
# Epoch 1,/3300, Current Loss = 1.1734
# Epoch 1,/3400, Current Loss = 1.2560
# Epoch 1,/3500, Current Loss = 1.1130
# Epoch 1,/3600, Current Loss = 1.1772
# Epoch 1,/3700, Current Loss = 1.3185
# Epoch 1,/3800, Current Loss = 1.2285
# Epoch 1,/3900, Current Loss = 1.2399
# Epoch 1,/4000, Current Loss = 1.1390
# Epoch 1,/4100, Current Loss = 1.1359
# Epoch 1,/4200, Current Loss = 1.1820
# Epoch 1,/4300, Current Loss = 1.2301
# Epoch 1,/4400, Current Loss = 1.1394
# Epoch 1,/4500, Current Loss = 1.1252
# Epoch 1,/4600, Current Loss = 1.1404
# Epoch 1,/4700, Current Loss = 1.0582
# Epoch 1,/4800, Current Loss = 1.1138
# Epoch 1,/4900, Current Loss = 1.2510
# Epoch 1,/5000, Current Loss = 1.1433
# Epoch 1,/5100, Current Loss = 1.0790
# Epoch 1,/5200, Current Loss = 1.0184
# Epoch 1,/5300, Current Loss = 1.0148
# Epoch 1,/5400, Current Loss = 1.1596
# Epoch 1,/5500, Current Loss = 1.0471
# Epoch 1,/5600, Current Loss = 0.9838
# Epoch 1,/5700, Current Loss = 1.0912
# Epoch 1,/5800, Current Loss = 1.0392
# Epoch 1,/5900, Current Loss = 1.0125
# Epoch 1,/6000, Current Loss = 0.9258
# Epoch 1,/6100, Current Loss = 1.1252
# Epoch 1,/6200, Current Loss = 1.0620
# Epoch 1,/6300, Current Loss = 1.0290
# Epoch 1,/6400, Current Loss = 1.0530
# Epoch 1,/6500, Current Loss = 1.1234
# Epoch 1,/6600, Current Loss = 1.0815
# Epoch 1,/6700, Current Loss = 1.0050
# Epoch 1,/6800, Current Loss = 0.9953
# Epoch 1,/6900, Current Loss = 1.0629
# Epoch 1,/7000, Current Loss = 0.9868
# Epoch 1,/7100, Current Loss = 1.0048
# Epoch 1,/7200, Current Loss = 1.1083
# Epoch 1,/7300, Current Loss = 0.9568
# Epoch 1,/7400, Current Loss = 1.0746
# Epoch 1,/7500, Current Loss = 0.9255
# Epoch 1,/7600, Current Loss = 0.9413
# Epoch 1,/7700, Current Loss = 1.0496
# Epoch 1,/7800, Current Loss = 0.8663
# Epoch 1,/7900, Current Loss = 0.9267
# Epoch 2,/100, Current Loss = 1.8840
# Epoch 2,/200, Current Loss = 0.9936
# Epoch 2,/300, Current Loss = 1.0838
# Epoch 2,/400, Current Loss = 0.9415
# Epoch 2,/500, Current Loss = 1.0256
# Epoch 2,/600, Current Loss = 1.0030
# Epoch 2,/700, Current Loss = 0.9144
# Epoch 2,/800, Current Loss = 0.9490
# Epoch 2,/900, Current Loss = 0.9521
# Epoch 2,/1000, Current Loss = 0.9427
# Epoch 2,/1100, Current Loss = 0.8353
# Epoch 2,/1200, Current Loss = 0.8453
# Epoch 2,/1300, Current Loss = 0.7898
# Epoch 2,/1400, Current Loss = 0.8447
# Epoch 2,/1500, Current Loss = 1.0908
# Epoch 2,/1600, Current Loss = 0.8563
# Epoch 2,/1700, Current Loss = 1.0621
# Epoch 2,/1800, Current Loss = 0.8815
# Epoch 2,/1900, Current Loss = 0.9073
# Epoch 2,/2000, Current Loss = 0.8881
# Epoch 2,/2100, Current Loss = 0.9175
# Epoch 2,/2200, Current Loss = 0.9282
# Epoch 2,/2300, Current Loss = 0.9651
# Epoch 2,/2400, Current Loss = 0.8705
# Epoch 2,/2500, Current Loss = 0.8505
# Epoch 2,/2600, Current Loss = 0.9773
# Epoch 2,/2700, Current Loss = 0.8377
# Epoch 2,/2800, Current Loss = 0.8064
# Epoch 2,/2900, Current Loss = 1.0426
# Epoch 2,/3000, Current Loss = 0.9104
# Epoch 2,/3100, Current Loss = 0.9373
# Epoch 2,/3200, Current Loss = 1.0082
# Epoch 2,/3300, Current Loss = 0.7325
# Epoch 2,/3400, Current Loss = 0.8387
# Epoch 2,/3500, Current Loss = 0.7365
# Epoch 2,/3600, Current Loss = 0.8459
# Epoch 2,/3700, Current Loss = 1.0056
# Epoch 2,/3800, Current Loss = 0.8689
# Epoch 2,/3900, Current Loss = 1.0003
# Epoch 2,/4000, Current Loss = 0.8616
# Epoch 2,/4100, Current Loss = 0.8509
# Epoch 2,/4200, Current Loss = 0.9437
# Epoch 2,/4300, Current Loss = 0.9516
# Epoch 2,/4400, Current Loss = 0.8801
# Epoch 2,/4500, Current Loss = 0.9147
# Epoch 2,/4600, Current Loss = 0.9035
# Epoch 2,/4700, Current Loss = 0.7905
# Epoch 2,/4800, Current Loss = 0.8465
# Epoch 2,/4900, Current Loss = 1.0246
# Epoch 2,/5000, Current Loss = 0.9491
# Epoch 2,/5100, Current Loss = 0.8839
# Epoch 2,/5200, Current Loss = 0.8335
# Epoch 2,/5300, Current Loss = 0.7931
# Epoch 2,/5400, Current Loss = 0.9367
# Epoch 2,/5500, Current Loss = 0.8862
# Epoch 2,/5600, Current Loss = 0.7934
# Epoch 2,/5700, Current Loss = 0.9010
# Epoch 2,/5800, Current Loss = 0.8608
# Epoch 2,/5900, Current Loss = 0.8130
# Epoch 2,/6000, Current Loss = 0.7431
# Epoch 2,/6100, Current Loss = 0.9543
# Epoch 2,/6200, Current Loss = 0.9167
# Epoch 2,/6300, Current Loss = 0.8810
# Epoch 2,/6400, Current Loss = 0.9214
# Epoch 2,/6500, Current Loss = 0.9735
# Epoch 2,/6600, Current Loss = 0.9139
# Epoch 2,/6700, Current Loss = 0.8311
# Epoch 2,/6800, Current Loss = 0.8421
# Epoch 2,/6900, Current Loss = 0.9114
# Epoch 2,/7000, Current Loss = 0.8358
# Epoch 2,/7100, Current Loss = 0.8622
# Epoch 2,/7200, Current Loss = 0.9650
# Epoch 2,/7300, Current Loss = 0.8105
# Epoch 2,/7400, Current Loss = 0.9634
# Epoch 2,/7500, Current Loss = 0.7856
# Epoch 2,/7600, Current Loss = 0.8183
# Epoch 2,/7700, Current Loss = 0.9640
# Epoch 2,/7800, Current Loss = 0.7295
# Epoch 2,/7900, Current Loss = 0.8095
# Epoch 3,/100, Current Loss = 1.6355
# Epoch 3,/200, Current Loss = 0.8631
# Epoch 3,/300, Current Loss = 0.9952
# Epoch 3,/400, Current Loss = 0.8275
# Epoch 3,/500, Current Loss = 0.9246
# Epoch 3,/600, Current Loss = 0.9065
# Epoch 3,/700, Current Loss = 0.7958
# Epoch 3,/800, Current Loss = 0.8459
# Epoch 3,/900, Current Loss = 0.8618
# Epoch 3,/1000, Current Loss = 0.8441
# Epoch 3,/1100, Current Loss = 0.7286
# Epoch 3,/1200, Current Loss = 0.7539
# Epoch 3,/1300, Current Loss = 0.6709
# Epoch 3,/1400, Current Loss = 0.7420
# Epoch 3,/1500, Current Loss = 0.9919
# Epoch 3,/1600, Current Loss = 0.7780
# Epoch 3,/1700, Current Loss = 0.9723
# Epoch 3,/1800, Current Loss = 0.7746
# Epoch 3,/1900, Current Loss = 0.8150
# Epoch 3,/2000, Current Loss = 0.7809
# Epoch 3,/2100, Current Loss = 0.8094
# Epoch 3,/2200, Current Loss = 0.8408
# Epoch 3,/2300, Current Loss = 0.8864
# Epoch 3,/2400, Current Loss = 0.7762
# Epoch 3,/2500, Current Loss = 0.7552
# Epoch 3,/2600, Current Loss = 0.8891
# Epoch 3,/2700, Current Loss = 0.7321
# Epoch 3,/2800, Current Loss = 0.7278
# Epoch 3,/2900, Current Loss = 0.9574
# Epoch 3,/3000, Current Loss = 0.8515
# Epoch 3,/3100, Current Loss = 0.8431
# Epoch 3,/3200, Current Loss = 0.9287
# Epoch 3,/3300, Current Loss = 0.6438
# Epoch 3,/3400, Current Loss = 0.7548
# Epoch 3,/3500, Current Loss = 0.6538
# Epoch 3,/3600, Current Loss = 0.7653
# Epoch 3,/3700, Current Loss = 0.9233
# Epoch 3,/3800, Current Loss = 0.8037
# Epoch 3,/3900, Current Loss = 0.9094
# Epoch 3,/4000, Current Loss = 0.8126
# Epoch 3,/4100, Current Loss = 0.7746
# Epoch 3,/4200, Current Loss = 0.8807
# Epoch 3,/4300, Current Loss = 0.8621
# Epoch 3,/4400, Current Loss = 0.8239
# Epoch 3,/4500, Current Loss = 0.8823
# Epoch 3,/4600, Current Loss = 0.8245
# Epoch 3,/4700, Current Loss = 0.7309
# Epoch 3,/4800, Current Loss = 0.7735
# Epoch 3,/4900, Current Loss = 0.9391
# Epoch 3,/5000, Current Loss = 0.8704
# Epoch 3,/5100, Current Loss = 0.8290
# Epoch 3,/5200, Current Loss = 0.7709
# Epoch 3,/5300, Current Loss = 0.7223
# Epoch 3,/5400, Current Loss = 0.8856
# Epoch 3,/5500, Current Loss = 0.8280
# Epoch 3,/5600, Current Loss = 0.7341
# Epoch 3,/5700, Current Loss = 0.8403
# Epoch 3,/5800, Current Loss = 0.7805
# Epoch 3,/5900, Current Loss = 0.7470
# Epoch 3,/6000, Current Loss = 0.6802
# Epoch 3,/6100, Current Loss = 0.8769
# Epoch 3,/6200, Current Loss = 0.8361
# Epoch 3,/6300, Current Loss = 0.8224
# Epoch 3,/6400, Current Loss = 0.8567
# Epoch 3,/6500, Current Loss = 0.9219
# Epoch 3,/6600, Current Loss = 0.8571
# Epoch 3,/6700, Current Loss = 0.7720
# Epoch 3,/6800, Current Loss = 0.7812
# Epoch 3,/6900, Current Loss = 0.8527
# Epoch 3,/7000, Current Loss = 0.7602
# Epoch 3,/7100, Current Loss = 0.8036
# Epoch 3,/7200, Current Loss = 0.8906
# Epoch 3,/7300, Current Loss = 0.7380
# Epoch 3,/7400, Current Loss = 0.8963
# Epoch 3,/7500, Current Loss = 0.7298
# Epoch 3,/7600, Current Loss = 0.7603
# Epoch 3,/7700, Current Loss = 0.9201
# Epoch 3,/7800, Current Loss = 0.6861
# Epoch 3,/7900, Current Loss = 0.7388
# Epoch 4,/100, Current Loss = 1.5126
# Epoch 4,/200, Current Loss = 0.7840
# Epoch 4,/300, Current Loss = 0.9543
# Epoch 4,/400, Current Loss = 0.7721
# Epoch 4,/500, Current Loss = 0.8787
# Epoch 4,/600, Current Loss = 0.8591
# Epoch 4,/700, Current Loss = 0.7395
# Epoch 4,/800, Current Loss = 0.7900
# Epoch 4,/900, Current Loss = 0.8296
# Epoch 4,/1000, Current Loss = 0.7974
# Epoch 4,/1100, Current Loss = 0.6744
# Epoch 4,/1200, Current Loss = 0.7076
# Epoch 4,/1300, Current Loss = 0.6152
# Epoch 4,/1400, Current Loss = 0.6862
# Epoch 4,/1500, Current Loss = 0.9328
# Epoch 4,/1600, Current Loss = 0.7385
# Epoch 4,/1700, Current Loss = 0.9232
# Epoch 4,/1800, Current Loss = 0.7147
# Epoch 4,/1900, Current Loss = 0.7607
# Epoch 4,/2000, Current Loss = 0.7287
# Epoch 4,/2100, Current Loss = 0.7538
# Epoch 4,/2200, Current Loss = 0.7852
# Epoch 4,/2300, Current Loss = 0.8348
# Epoch 4,/2400, Current Loss = 0.7270
# Epoch 4,/2500, Current Loss = 0.6979
# Epoch 4,/2600, Current Loss = 0.8414
# Epoch 4,/2700, Current Loss = 0.6616
# Epoch 4,/2800, Current Loss = 0.6790
# Epoch 4,/2900, Current Loss = 0.8945
# Epoch 4,/3000, Current Loss = 0.8050
# Epoch 4,/3100, Current Loss = 0.7762
# Epoch 4,/3200, Current Loss = 0.8740
# Epoch 4,/3300, Current Loss = 0.5816
# Epoch 4,/3400, Current Loss = 0.6885
# Epoch 4,/3500, Current Loss = 0.6155
# Epoch 4,/3600, Current Loss = 0.7184
# Epoch 4,/3700, Current Loss = 0.8721
# Epoch 4,/3800, Current Loss = 0.7527
# Epoch 4,/3900, Current Loss = 0.8598
# Epoch 4,/4000, Current Loss = 0.7764
# Epoch 4,/4100, Current Loss = 0.7186
# Epoch 4,/4200, Current Loss = 0.8298
# Epoch 4,/4300, Current Loss = 0.8088
# Epoch 4,/4400, Current Loss = 0.7791
# Epoch 4,/4500, Current Loss = 0.8404
# Epoch 4,/4600, Current Loss = 0.7827
# Epoch 4,/4700, Current Loss = 0.6809
# Epoch 4,/4800, Current Loss = 0.7181
# Epoch 4,/4900, Current Loss = 0.9029
# Epoch 4,/5000, Current Loss = 0.8140
# Epoch 4,/5100, Current Loss = 0.7910
# Epoch 4,/5200, Current Loss = 0.7248
# Epoch 4,/5300, Current Loss = 0.6686
# Epoch 4,/5400, Current Loss = 0.8337
# Epoch 4,/5500, Current Loss = 0.7873
# Epoch 4,/5600, Current Loss = 0.6995
# Epoch 4,/5700, Current Loss = 0.7917
# Epoch 4,/5800, Current Loss = 0.7196
# Epoch 4,/5900, Current Loss = 0.7017
# Epoch 4,/6000, Current Loss = 0.6290
# Epoch 4,/6100, Current Loss = 0.8253
# Epoch 4,/6200, Current Loss = 0.7792
# Epoch 4,/6300, Current Loss = 0.7816
# Epoch 4,/6400, Current Loss = 0.7966
# Epoch 4,/6500, Current Loss = 0.8842
# Epoch 4,/6600, Current Loss = 0.8001
# Epoch 4,/6700, Current Loss = 0.7360
# Epoch 4,/6800, Current Loss = 0.7302
# Epoch 4,/6900, Current Loss = 0.8137
# Epoch 4,/7000, Current Loss = 0.6969
# Epoch 4,/7100, Current Loss = 0.7610
# Epoch 4,/7200, Current Loss = 0.8377
# Epoch 4,/7300, Current Loss = 0.6740
# Epoch 4,/7400, Current Loss = 0.8556
# Epoch 4,/7500, Current Loss = 0.6846
# Epoch 4,/7600, Current Loss = 0.7111
# Epoch 4,/7700, Current Loss = 0.8702
# Epoch 4,/7800, Current Loss = 0.6546
# Epoch 4,/7900, Current Loss = 0.6807

# %%
def test(print_every=5000):
    accuracy = 0
    num_of_letters = 0
    with torch.no_grad():

        for counter, (english_name, hebrew_name) in enumerate(dev_data):
            encoder_hidden = encoder_model.initHidden()

           

            encoder_outputs = torch.zeros(len(english_name), 1, encoder_model.hidden_size).cuda()
    
            for i, letter in enumerate(english_name):
                letter_tensor = torch.tensor([[letter]]).cuda()
                encoder_output, encoder_hidden = encoder_model(letter_tensor, encoder_hidden)
                
                encoder_outputs[i] = encoder_output
            
            decoder_input = torch.tensor([[0]]).cuda()
            decoder_hidden = encoder_hidden
            
            guessed_word = []
            
            for i in range(len(hebrew_name)):
                decoder_output, decoder_hidden = decoder_model(decoder_input, decoder_hidden, encoder_outputs)
                
                
                _, top_indexes = decoder_output.topk(1)
#                 print(decoder_output.size())
                decoder_input = top_indexes.squeeze(0).detach()
#                 print(torch.max(decoder_output,dim=2).indices.size())
                guessed_word.append(torch.max(decoder_output,dim=2).indices[0])
                
#                 print(decoder_output.size())
#                 if decoder_input.item() == [1]:
#                     break
            
            for i in range(MAX_LABEL_LENGTH):
                if guessed_word[i] == hebrew_name[i] and guessed_word[i] == 1:
                    break
                
                num_of_letters += 1
                if guessed_word[i] == hebrew_name[i]:
                    accuracy += 1

        
            if counter % print_every == 0 and counter != 0:
                print(counter)
    print(accuracy / num_of_letters)

# %%
test(print_every=500)
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 0.5646833747847714
